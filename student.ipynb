# %% [markdown]
# ![Aspriring.JPG](https://raw.githubusercontent.com/andrewwongls/dsc-4-final-project-online-ds-sp-000/master/Aspriring.JPG)

# %% [markdown]
# This was my journey. 72 hours in total.

# %% [markdown]
# ![Executive%20Summary2.jpg](https://raw.githubusercontent.com/andrewwongls/dsc-4-final-project-online-ds-sp-000/master/Executive%20Summary2.jpg)

# %% [markdown]
# The intention of this notebook is first and foremost to showcase how I would run an end-to-end data science project based on Lending Club dataset and its domain problems. Second, from here with the data insights in hand, I will take you reader on a journey on how I will create AI/Machine Learning product/services.
#
# I will be walking you through the following core objectives (more details in the following sections):
#
# **PRODUCT-DRIVEN**
#
# **1. Identify and Solve** critical Lending Club's business objectives/domain problems in the areas of finance, operations, marketing through machine learning and statistical methodologies.
#
# **2. Develop** agile data science approach that focuses on multiple iterations, collaboration with stakeholders, responding to change, and demonstrating working machine learning models.
#
# **DATA SCIENCE-DRIVEN**
#
# **3. Discover and Build** new data insight through the OSEMN data science framework.
#
# **4. Explore, Formulate, and Predict** Lending Club loan default and loss in investment. The objective is to model/engineer a predictive model that could determine a good and bad loan before and during the loan approval process.
#
# **5. Use** Design of Experiments (DoE) to explore new way looking at the domain problem, design the right testing/validation framework, and to monitor the efficacy of modeling/processes.
#
#
# #### SUMMARY OF PREDICTIVE MODELING RESULTS
#
# Let's summarize based on what we have produced so far.
#
# > **Predictive Modeling Based on Logistic Regressio, Random Forest, XGBoost, and SVM - Test Accuracy Results**
#
# Logistic Regression: 78.5%
#
# Random Forest      : 78.5%
#
# XGBoost            : 77.2%
#
# SVM                : 78.5%
#
#
# > **Predictive Modeling Based on Deep Neural Network**
#
# Layer 1: 79%
#
# Layer 2: 78%
#
# Layer 3: 79%
#
#
# > **Top 5 Predictors Based on Random Forest Relative Features Importance:**
#
# 1. Annual income
#
# 2. Revolving balance
#
# 3. Total account
#
# 4. FICO score
#
# 5. DTI

# %% [markdown]
# # TABLE OF CONTENT
#
# ## INTRODUCTION
# ## PART 1 OBTAIN DATA
# ## PART 2 SCRUBBING DATA
# ## PART 3 EXPLORING DATA
# ## PART 4 MODEL DATA
# ## PART 5 INTERPRET DATA
#
# ## CONCLUSION

# %% [markdown]
# ![Introduction2.jpg](https://raw.githubusercontent.com/andrewwongls/dsc-4-final-project-online-ds-sp-000/master/Introduction2.jpg)

# %% [markdown]
# Welcome!
# I am going to deep dive into LendingClub.
#
# In this Introduction Section, I do like to talk about LendingClub's business model, customer value proposition (investors and borrowers), and the way LendingClub uses data to gain competitive advantage.
#
# LendingClub is one of the key players in the peer-to-peer lending platform. Other competitors include SoFi, Prosper, KivaZip, Upstart, Street Shares, and OnDeck. The barriers to entry into the peer-to-peer lending platform is relatively low (as compared to setting up a banking institution due to deposit taking licenses, etc.), therefore there are future expectations that more newcomers will emerge with more exciting and innovative products in the near future. For example, with the recent announcement of Facebook's Libra cryptocurrency; this will further open up brand new world of opportunities for peer-to-peer lending and other new to world financial services.
#
# In brief, LendingClub's business model revolves around cutting off the middle banking institutions in the traditional lending process. Their value proposition is to provide higher return for individuals investors, and at the same time, lower interests for borrowers. Here are some brief details of what they are offerings:
# 1. Term Amounts – Normally ranges between 1,000 to 400,000 Dollars.
# 2. Term Lengths – Usually between three (3) to five (5) years.
# 3. APRs – Typically between 5.99 percent (5.99%) to 35.89 percent (35.89%) based on your credit score.
#
# From investors' perspective, when they are investing directly into borrowers via LendingClub. They are in fact investing in LendingClub's Notes. In another words, when investors invest at LendingClub, they are not making loans directly to the borrower, instead, they are investing in SEC-registered securities called Member Payment Dependent Notes, or “Notes,” which correspond to fractions of loans. As borrowers make their monthly loan payments of principal and interest, LendingClub takes out applicable fees and deposits the portion corresponding to investors' Note into investors' account.

# %% [markdown]
# ![The%20Matching%20Game.JPG](https://raw.githubusercontent.com/andrewwongls/dsc-4-final-project-online-ds-sp-000/master/The%20Matching%20Game.JPG)

# %% [markdown]
# LendingClub has done most of the homework/hardwork for investors in the form of managing investment risks. Here's an excerpt from their website about how they help investors to manage investemnt risks:
# 1. Grades and sub-grades: LendingClub assigns a grade (A–D) and sub-grade (1-5) to each Note, which reflects LendingClub’s assessment of the credit risk of the corresponding loan. For example, if the borrower has a weaker credit profile they would get a lower grade and sub-grade, like D5. If the borrower has a stronger credit history, they’d get a higher grade and sub-grade, like A1 or B1.
# 2. Interest rates: The stated interest rate on each Note varies depending on the credit risk of the corresponding loan. So higher grade Notes (higher credit quality) come with lower interest rates. Lower grade Notes come with higher interest rates to factor in the risk you’re taking on by investing in weaker credit.
# 3. Terms: Loans mature in 3-or 5-years and are paid off monthly by borrowers. Each payment includes both interest and principal. Know that borrowers can pre-pay their full loan amounts and are not subject to any early payment fees or penalties.
#
# In sum, LendingClub has a ready-made formulation of grading and sub-grading each Notes. Therefore, grade and sub-grade is a direct way for LendingClub and investors to assess risk of each Notes.
#
# I will be walking through three lens. First, data science-driven. Second, product-driven. Third, production-driven.
#
# **PRODUCT-DRIVEN**
#
# While working through the data science workflow, I will work consciously to identify and solve critical LendingClub's business objectives/domain problems in the areas of finance, operations, marketing through machine learning and statistical methodologies.
#
# More importantly, I will be exploring the opportunities to leverage and develop agile data science and design sprinting approach that focuses on multiple iterations, collaboration with stakeholders, responding to change, and demonstrating working machine learning models. I hope my current backgrounds in these two areas (i.e. agile development and design sprint) will serve to advance the understanding and synthesis of agile data science. This will ultimately translates into a case study for LendingClub on how to run a product-driven data science project.
#
#
# **DATA SCIENCE-DRIVEN**
#
# In additional of consciously running a data science project in a product-driven way, I will follow the discipline of discovering and building new data insight through the OSEMN data science framework.
#
# At the heart of this project, I will explore, formulate, and predict LendingClub's loan default and loss in investment. The objective is to model/engineer a predictive model that could determine a good and bad loan before and during the loan approval process.
#
# In order to model and engineer a predictive model, I will leverage on the discipline of using Design of Experiments (DoE) to explore new way looking at the domain problem, design the right testing/validation framework, and to monitor the efficacy of modeling/process.
#
# **MACHINE LEARNING PRODUCTION-DRIVEN**
#
# Lastly, I attempt to bridge The Gap between data science and machine learning in production by examining the architectural and design decisions to optimize what matters in production - highest return-on-investment, and data quality (accuracy, integrity, consistency, completeness, and auditability).

# %% [markdown]
# The diagram below (The Big Picture) illustrates the Big Picture of why, what and how I will proceed work from the start of design sprinting (begin with the customers in mind), next working through the data science workflow, and finally getting to Minimum Viable Product (MVP) and Minimum Marketable Product (MMP). While I am working through all these steps/process, the underlying framework is supported by cycling iteratively through agile development and delivery.

# %% [markdown]
# ![The%20Big%20Picture.JPG](https://raw.githubusercontent.com/andrewwongls/dsc-4-final-project-online-ds-sp-000/master/The%20Big%20Picture.JPG)

# %% [markdown]
# ### DESIGN SPRINT (DAY 1 - UNDERSTANDING TARGET PROBLEM)

# %% [markdown]
# The LendingClub dataset is published by LendingClub itself based on the all the accepted/approved loans issues between 2007 and Quarter 4, 2018. The diagram below (The Data Science - Predictive Analytics: Decision - Data - Prediction) summarizes where I want to take the reader of this project.
#
# DECISION: At the start, what is the key decision here. It is essentially, what and how to minimize investors' financial risks.
#
# DATA: Next, the current view is that we have LendingClub's dataset up to Q4 2018 and some public published data about default loans. So, aside from these data, what are the alternative data that we can leverage to build a better picture of financial risks. I am suggesting to use both backward looking data (or known as lagging indicators) such as macroeconomics data, competitive data (data from Prosper, Upshot, etc.), and profile data about borrowers. These alternative views will provide insights that cannot be forecasted by just machine learning or predictive analytics alone. Of course, we can use our imaginative mind to forward look (or known as leading indicators). This is essentially to break from the past and start to design forward.
#
# PREDICTION: Here we will be using simple machine learning (e.g. logistic regression) and deep neural network (DNN) to predict bad or good loan before and during the loan approval process.

# %% [markdown]
# ![Decision-Data-Prediction.JPG](https://raw.githubusercontent.com/andrewwongls/dsc-4-final-project-online-ds-sp-000/master/Decision-Data-Prediction.JPG)

# %% [markdown]
# ### DESIGN SPRINT (DAY 2 AND 3 - MAP SKETCH AND DECIDE ON COMPETING SOLUTION/ ALGORITHM THAT BEST SOLVE TARGET PROBLEM)

# %% [markdown]
# At the very core, we are trying to differentiate bad and good loan. The intention here is to design/engineer predictive modeling that will help us to get there. We will first try to understand the kind of data that we have in hand. Then, we have a collection of algorithms that we can use to help us get there.

# %% [markdown]
# ![The%20Decisions%20Map%20in%20Data%20Science.JPG](https://raw.githubusercontent.com/andrewwongls/dsc-4-final-project-online-ds-sp-000/master/The%20Decisions%20Map%20in%20Data%20Science.JPG)

# %% [markdown]
# ### HOW I SPENT MY TIME AS A PRODUCT DATA SCIENTIST

# %% [markdown]
# Before I start to go through the data science workflow, I'd like to share the percentage time effort split that a data scientist like myself invested in a typical project with the ultimate aim of churning out product/service ideas.
#
# Prior to any project, I have invested significant of time in understanding the industry domain knowledge that I will be working on. In this case, I invested time to understand the peer-to-peer lending (why and what are the differences as compared to traditional banking lending), competitive analysis (who else in the peer-to-peer lending marketplace), and customer analysis (why there is demand for peer-to-peer lending).
#
# Next, I have invested about 40% of my time effort in scrubbing/cleaning the LendingClub dataset. This is one of the crucial part of being a data scientist - getting the dataset ready for feature engineering and predictive modeling. The main parts of data scrubbing consist of cleaning the missing value, checking for multicollinearity, and scrubbing categorical and numerical data.
#
# Then, the next most crucial task is feature engineering. According to Andrew Ng, "Coming up with features is difficult, time-consuming, requires expert knowledge. “Applied machine learning” is basically feature engineering." The data science workflow (like OSEMN workflow) is fluid and iterative, so there’s no one right or optimum answer. Essentially, feature engineering is all things on creating and designing new features from existing dataset to improve predictive model performance.
#
# The next tasks that I am about to describe will likely be new to most data scientists.
#
# I realize that being better in designing a product/services from predictive modeling is a far more valuable and creative part of data science. It is about being able to leverage from what we have just learned. It is about being able to translate predictive modeling into potential product modeling (aka designing).
#
# This is something that I enjoy doing - project storytelling. This is about weaving all the threads what you have learned so far into a cohensive and memorable stories. This is the selling-side of data science i.e. the ability to show-and-tell what you have learned and what are the next steps.

# %% [markdown]
# ![My%20Percentage%20Time.JPG](https://raw.githubusercontent.com/andrewwongls/dsc-4-final-project-online-ds-sp-000/master/My%20Percentage%20Time.JPG)

# %% [markdown]
# ## IMPORTING NECESSARY LIBRARIES

# %%
# importing necessary libraries

import pandas as pd
from pandas.tools import plotting
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import chart_studio as py
import plotly.graph_objs as go
from plotly import tools
from plotly.offline import init_notebook_mode, plot, iplot
import seaborn as sns
import xgboost as xgb
from datetime import datetime
import warnings
warnings.filterwarnings(action='ignore')

# %matplotlib inline
plt.style.use('seaborn')
mpl.style.use('ggplot')
sns.set(style='whitegrid')

# importing map visulization libraries
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)

# importing Sci-kit Learn libraries
from sklearn import svm
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, MinMaxScaler, Imputer, OneHotEncoder, LabelEncoder
from sklearn.pipeline import Pipeline, make_pipeline, FeatureUnion
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.metrics import classification_report, accuracy_score, roc_curve, confusion_matrix, precision_score, recall_score, f1_score
from sklearn.impute import SimpleImputer
from sklearn import preprocessing

# importing Sci-py libraries
from scipy.stats import ttest_ind

# importing statsmodels to perform statistical analysis
import statsmodels.api as sm
from scipy import stats
from scipy.stats import chi2_contingency
from scipy.stats import chisquare
from statsmodels.formula.api import ols

# importing Predictive Analytics/ Machine Learning libraries
from xgboost import XGBClassifier
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras import regularizers

# for oversampling library (dealing with Imbalanced Datasets)
from imblearn.over_sampling import SMOTE
from collections import Counter

# other libraries
import time

# printing style available
print(plt.style.available)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# Using TensorFlow backend.
# ...

# %% [markdown]
# ![Data%20Obtain2.jpg](https://raw.githubusercontent.com/andrewwongls/dsc-4-final-project-online-ds-sp-000/master/Data%20Obtain2.jpg)

# %% [markdown]
# ## PART 1 OBTAINING THE LENDING CLUB DATASET
#
# ### (Including Bonus Initial Data Exploration)

# %%
# extracting Lending Club dataset for a quick feel of the available columns and rows

accepted_loans = pd.read_csv('accepted_2007_to_2018Q4.csv.gz', compression='gzip', low_memory=True)
accepted_loans.head(10)
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68407277        NaN     3600.0       3600.0           3600.0   36 months
# 1  68355089        NaN    24700.0      24700.0          24700.0   36 months
# 2  68341763        NaN    20000.0      20000.0          20000.0   60 months
# 3  66310712        NaN    35000.0      35000.0          35000.0   60 months
# 4  68476807        NaN    10400.0      10400.0          10400.0   60 months
# 5  68426831        NaN    11950.0      11950.0          11950.0   36 months
# 6  68476668        NaN    20000.0      20000.0          20000.0   36 months
# 7  67275481        NaN    20000.0      20000.0          20000.0   36 months
# 8  68466926        NaN    10000.0      10000.0          10000.0   36 months
# 9  68616873        NaN     8000.0       8000.0           8000.0   36 months
#
#    int_rate  installment grade sub_grade       ...        \
# 0     13.99       123.03     C        C4       ...
# ...

# %%
accepted_loans.describe()
# Out:
#        member_id     loan_amnt   funded_amnt  funded_amnt_inv      int_rate  \
# count        0.0  2.260668e+06  2.260668e+06     2.260668e+06  2.260668e+06
# mean         NaN  1.504693e+04  1.504166e+04     1.502344e+04  1.309283e+01
# std          NaN  9.190245e+03  9.188413e+03     9.192332e+03  4.832138e+00
# min          NaN  5.000000e+02  5.000000e+02     0.000000e+00  5.310000e+00
# 25%          NaN  8.000000e+03  8.000000e+03     8.000000e+03  9.490000e+00
# 50%          NaN  1.290000e+04  1.287500e+04     1.280000e+04  1.262000e+01
# 75%          NaN  2.000000e+04  2.000000e+04     2.000000e+04  1.599000e+01
# max          NaN  4.000000e+04  4.000000e+04     4.000000e+04  3.099000e+01
#
#         installment    annual_inc           dti   delinq_2yrs  fico_range_low  \
# count  2.260668e+06  2.260664e+06  2.258957e+06  2.260639e+06    2.260668e+06
# mean   4.458068e+02  7.799243e+04  1.882420e+01  3.068792e-01    6.985882e+02
# ...

# %% [markdown]
# There are 151 columns ranging from ID to settlement terms, with a huge memory usage and more than 2 millions rows (to be exact 2,260,7001). The memory usage is very high. In fact, it is too high for local processing at 2.5+ Gigabit! More about this large memory usage, and how it crashes my local processing hardward.

# %%
accepted_loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2260701 entries, 0 to 2260700
# Columns: 151 entries, id to settlement_term
# dtypes: float64(113), object(38)
# memory usage: 2.5+ GB

# %% [markdown]
# ### INITIAL DATA EXPLORATION THROUGH VISUALIZATION

# %% [markdown]
# #### INITIAL DATA EXPLORATION 1: LOAN ISSUANCE TREND OVER LAST 12 YEARS FOR LENDINGCLUB

# %%
# transforming the issue dates by year

accepted_loans['issue_d'].head()
dt_series = pd.to_datetime(accepted_loans['issue_d'])
accepted_loans['year'] = dt_series.dt.year

# %% [markdown]
# The chart below shows an ever increasing issuance of loans since the start of Global Financial Crisis (GFC) in 2008. This is in line with the logic of the more hardship, the higher demands for loans from borrowers. However, it is somehow peaked around 2015, seven years after GFC. This is an indication of the de-leveraging cycle, where Americans continue to reduce debt burdens when possible. Also, it is possible that there are more peer-to-peer competitors coming into the marketplace to grab more marketshare.
#
# In 2018, LendingClub's average loans issued started to grow again. This may indicates the borrowing needs increases due to either personal (e.g. more confident to borrow), investors' appetite (e.g. taking higher risk) or macroeconomic factors. It has been 10 years since GFC, perhaps these are early signals of boom-and-bust cycle appearing again?

# %%
# uncovering issuance of loans over last 12 years of LendingClub's operations

plt.figure(figsize=(10,8))
sns.barplot('year', 'loan_amnt', data=accepted_loans, palette='PuBu')
plt.title('Issuance of Loans', fontsize=20)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Average Loan Amount Issued', fontsize=14)
# Out:
# Text(0, 0.5, 'Average Loan Amount Issued')

# %% [markdown]
# #### INITIAL DATA EXPLORATION 2: WHAT WE KNOW TODAY - THE GOOD AND BAD LOANS
#
# Let's examine a bit in details on the current statistics derived from LendingClub's dataset on bad and good loans.
#
# The good loans now is at 87%. Since 2007, it the percentage good loans over bad loans have grown over time. This is an indication of LendingClub success in predicting and filtering good loans for investors.

# %%
# determining the loans that are bad based on loan status

bad_loan = ["Charged Off", "Default", "Does not meet the credit policy. Status:Charged Off", "In Grace Period", "Late (16-30 days)", "Late (31-120 days)"]
accepted_loans['loan_condition'] = np.nan
def loan_condition(status):
    if status in bad_loan:
        return 'Bad Loan'
    else:
        return 'Good Loan'
    
accepted_loans['loan_condition'] = accepted_loans['loan_status'].apply(loan_condition)

# %%
# quick overview of bad and good loans

f, ax = plt.subplots(1,2, figsize=(25,15))

colors = ["#12DCB2", "#DC133C"]
labels ="Good Loans", "Bad Loans"

plt.suptitle('The Good and Bad', fontsize=25)
accepted_loans["loan_condition"].value_counts().plot.pie(explode=[0,0.25], autopct='%1.2f%%', ax=ax
[0], shadow=True, colors=colors,
labels=labels, fontsize=15, startangle=70)

ax[0].set_ylabel('% of Condition of Loans', fontsize=15)

palette = ["#12DCB2", "#DC133C"]
sns.barplot(x="year", y="loan_amnt", hue="loan_condition", data=accepted_loans, palette=palette,
estimator=lambda x: len(x) / len(accepted_loans) * 100)
ax[1].set(ylabel="(%)")
# Out:
# [Text(0, 0.5, '(%)')]

# %% [markdown]
# #### INITIAL DATA EXPLORATION 3: QUICK OVERVIEW OF LOAN ISSUANCE BASED ON US REGIONS

# %%
accepted_loans['addr_state'].unique()

# listing with each of the regions by state
west = ['CA', 'OR', 'UT','WA', 'CO', 'NV', 'AK', 'MT', 'HI', 'WY', 'ID']
south_west = ['AZ', 'TX', 'NM', 'OK']
south_east = ['GA', 'NC', 'VA', 'FL', 'KY', 'SC', 'LA', 'AL', 'WV', 'DC', 'AR', 'DE','MS', 'TN' ]
mid_west = ['IL', 'MO', 'MN', 'OH', 'WI', 'KS', 'MI', 'SD', 'IA', 'NE', 'IN', 'ND']
north_east = ['CT', 'NY', 'PA', 'NJ', 'RI','MA', 'MD', 'VT', 'NH', 'ME']
accepted_loans['region'] = np.nan
def finding_regions(state):
    if state in west:
        return 'West'
    elif state in south_west:
        return 'SouthWest'
    elif state in south_east:
        return 'SouthEast'
    elif state in mid_west:
        return 'MidWest'
    elif state in north_east:
        return 'NorthEast'

accepted_loans['region'] = accepted_loans['addr_state'].apply(finding_regions)

# %%
# transforming current dates into a year-month format

accepted_loans['complete_date'] = pd.to_datetime(accepted_loans['issue_d'])

group_dates = accepted_loans.groupby(['complete_date', 'region'], as_index=False).sum()

group_dates['issue_d'] = [month.to_period('M') for 
                          month in group_dates['complete_date']]

group_dates = group_dates.groupby(['issue_d', 'region'], as_index=False).sum()
group_dates = group_dates.groupby(['issue_d', 'region'], as_index=False).sum()
group_dates['loan_amnt'] = group_dates['loan_amnt']/1000


accepted_loans_dates = pd.DataFrame(data=group_dates[['issue_d','region','loan_amnt']])

# %% [markdown]
# The lowest loan issued by LendingClub is in the SouthWest Region, and the highest in the SouthEast.

# %%
plt.style.use('dark_background')
cmap = plt.cm.Set3
by_issued_amount = accepted_loans_dates.groupby(['issue_d', 'region']).loan_amnt.sum()
by_issued_amount.unstack().plot(stacked=False, colormap=cmap, grid=False, legend=True,
figsize=(15,6))
plt.title('Quick Overview of Loan Issuance based on US Regions', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Quick Overview of Loan Issuance based on US Regions')

# %% [markdown]
# #### INITIAL DATA EXPLORATION 4: QUICK OVERVIEW OF DISTRIBUTION OF LOAN AMOUNTS BY LOAN STATUS

# %% [markdown]
# The naive view (quick, snap judgement) is that the lower the loan amounts, the lower the probability of defaulting a loan or a loan becoming bad. This is clear especially those loan statuses - in-grace period, late (31-120 days), and late (16-30 days) - all of them exhibited higher loan amount as compared to Fully Paid status. The loan amount difference is $5000 between good and bad loans.

# %%
plt.subplots(figsize=(18,9))
plt.title("The Distribution of Loan Amounts by Loan Status").set_size(36)
sns.boxplot(x="loan_amnt", y="loan_status", data=accepted_loans)

# %% [markdown]
# #### INITIAL DATA EXPLORATION 5: WHAT IS INVESTORS RISK APPETITE BASED ON GRADE AND LOAN AMOUNT

# %% [markdown]
# There is a natural tendency for investors to invest more in lower grade loans; it is likely that the higher the risk, the higher the return (higher borrowing interest). Also, there is a tendency that there is (almost) always higher loan applications coming from lower grade borrowers.

# %%
group = accepted_loans.groupby("grade").mean()
avg_loan = group['loan_amnt'].reset_index()
plt.subplots(figsize=(15,9))
sns.barplot(x='grade', y='loan_amnt', data=avg_loan, palette='Set2')

# %% [markdown]
# #### INITIAL DATA EXPLORATION 6: QUICK OVERVIEW OF INTEREST RATE IN RELATION TO LOAN GRADING

# %% [markdown]
# There is no surprise here - the lower the loan grade, the higher borrowing interest rate. What is interesting is the fact that if a person is in Grade A, he/she enjoys at least 15% lower borrowing interest rate than a Grade G person. Based on LendingClub' data, we know that the average loan amount in 2018 is USD 16,000 . So that's roughly USD 2,400 saving for a Grade A person over the lifetime of the loan.

# %%
plt.subplots(figsize=(15,6))
sns.violinplot(x="grade", y="int_rate", data=accepted_loans, order="ABCDEFG")

# %% [markdown]
# ![Data%20Scrubbing2.jpg](https://raw.githubusercontent.com/andrewwongls/dsc-4-final-project-online-ds-sp-000/master/Data%20Scrubbing2.jpg)

# %% [markdown]
# ## PART 2 SCRUBBING THE LENDING CLUB DATASET

# %% [markdown]
# The dataset contains all the accepted/approved loans ranging from fully paid (highest count) to default (lowest count). At this point, we will need to be conscious that the higher default data can be hidden because some form of risk assessment has been done to assess each Notes default risk. Put simply, the default data has been risk assessed by LendingClub.

# %%
# checking the currently accepted loan by LendingClub.

accepted_loans['loan_status'].value_counts(normalize=True)
# Out:
# Fully Paid                                             0.476298
# Current                                                0.388521
# Charged Off                                            0.118796
# Late (31-120 days)                                     0.009496
# In Grace Period                                        0.003732
# Late (16-30 days)                                      0.001924
# Does not meet the credit policy. Status:Fully Paid     0.000879
# Does not meet the credit policy. Status:Charged Off    0.000337
# Default                                                0.000018
# Name: loan_status, dtype: float64

# %% [markdown]
# #### DATA PROCESSING 1: MERGING NECESSARY DATA
#
# After further preprocessing the dataset with interest only on fully paid and charged off, the dataset has dropped to about 1.3 millions row from 2.26 millions row.

# %%
# dropping rows not in 'Fully Paid' or 'Charged Off' because we are interested in predicting either a bad or good Notes.

accepted_loans = accepted_loans.loc[accepted_loans['loan_status'].isin(['Fully Paid', 'Charged Off','Does not meet the credit policy. Status:Fully Paid',
'Does not meet the credit policy. Status:Charged Off'])]
accepted_loans.shape
# Out:
# (1348059, 155)

# %%
# merging the Does not meet the credit policy into fully paid or charged off

accepted_loans.loan_status.replace(to_replace='Does not meet the credit policy. Status:Fully Paid',
value= 'Fully Paid', inplace=True)
accepted_loans.loan_status.replace(to_replace='Does not meet the credit policy. Status:Charged Off',
value= 'Charged Off', inplace=True)

# %% [markdown]
# A quick check on the dataset, now we have Fully Paid and Charged Off, we are ready to go.

# %%
# fast checking whether we are ready to go next step

accepted_loans['loan_status'].value_counts(normalize=True)
# Out:
# Fully Paid     0.800216
# Charged Off    0.199784
# Name: loan_status, dtype: float64

# %% [markdown]
# #### DATA PROCESSING 2: RESOLVING MISSING VALUES

# %%
# scanning of missing values in percentage and count

accepted_loans_null = pd.DataFrame({'Count': accepted_loans.isnull().sum(), 'Percent': 100*accepted_loans.isnull().sum()/len(accepted_loans)})

# printing columns with null count more than 0

accepted_loans_null[accepted_loans_null['Count'] > 0]
# Out:
#                                               Count     Percent
# member_id                                   1348059  100.000000
# emp_title                                     85944    6.375389
# emp_length                                    78545    5.826525
# annual_inc                                        4    0.000297
# desc                                        1222104   90.656566
# title                                         16661    1.235925
# zip_code                                          1    0.000074
# dti                                             374    0.027744
# delinq_2yrs                                      29    0.002151
# earliest_cr_line                                 29    0.002151
# inq_last_6mths                                   30    0.002225
# mths_since_last_delinq                       679942   50.438594
# mths_since_last_record                      1118644   82.981828
# open_acc                                         29    0.002151
# ...

# %%
# removing columns missing 15% of data

accepted_loans2 = accepted_loans.dropna(axis=1, thresh=int(0.75*len(accepted_loans)))

# %% [markdown]
# Based on the data shape, after cleaning the missing values, the columns are reduced from 151 to 93.

# %%
accepted_loans2.shape
# Out:
# (1348059, 97)

# %%
# listing of remaining features so far
print(sorted(accepted_loans2.columns))
# Out:
# ['acc_now_delinq', 'acc_open_past_24mths', 'addr_state', 'annual_inc', 'application_type', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util', 'chargeoff_within_12_mths', 'collection_recovery_fee', 'collections_12_mths_ex_med', 'complete_date', 'debt_settlement_flag', 'delinq_2yrs', 'delinq_amnt', 'disbursement_method', 'dti', 'earliest_cr_line', 'emp_length', 'emp_title', 'fico_range_high', 'fico_range_low', 'funded_amnt', 'funded_amnt_inv', 'grade', 'hardship_flag', 'home_ownership', 'id', 'initial_list_status', 'inq_last_6mths', 'installment', 'int_rate', 'issue_d', 'last_credit_pull_d', 'last_fico_range_high', 'last_fico_range_low', 'last_pymnt_amnt', 'last_pymnt_d', 'loan_amnt', 'loan_condition', 'loan_status', 'mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl', 'mort_acc', 'mths_since_recent_bc', 'mths_since_recent_inq', 'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl', 'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl', 'num_rev_a
# ...

# %% [markdown]
# #### FEATURE ENGINEERING 1: FINDING MEANINGFUL PREDICTOR FEATURES
#
# After data preprocessing, I would consider feature engineering exercise is the next most important task for data scientist. It is all about creating and designing new features from the current dataset to improve predictive model performance. Put simply, it is enabling our predictive model algorithm to focus on what are important predictor features by highlighting it beforehand.
#
# I have reviewed LendingClub's data dictionary to understand the meaning and descriptions behind each features. I have categorized features into the following:
# 1. Borrowers' profile (e.g. employment length).
# 2. Borrowers' financial risk assessment (e.g. delinquency in the past two years).
# 3. Borrowers' external credit assessment (e.g. public record of bankruptcies).
#
# ![Feature%20Engineering.JPG](attachment:Feature%20Engineering.JPG)
#
# More importantly in feature engineering exercise is what are the features being taken out. This really depends on the goal or our problem statement. Just to recap, the project's problem statement is to predict whether the loan is bad or good loans (in LendingClub terms either a good or bad Notes). Therefore, the focus here is to focus on features of borrowers' profile and financial risk that we knew BEFORE the loan was invested.
#
# Some of the features that are:
# 1. UNRELATED: Service fee rate paid by the investor for this loan, and number of finance trades.
# 2. LENDINGCLUB'S OWN ASSESSMENT: Grade, sub-grade, and the expected default rate of the loan.
# 3. POST-INVESTMENT INFORMATION: interest repayment, and installment.

# %%
# keeping the features after going through LendingClub's data dictionary

keep_list = ['acc_now_delinq', 'annual_inc', 'application_type', 'collections_12_mths_ex_med',
'delinq_2yrs', 'delinq_amnt', 'dti', 'emp_length', 'emp_title', 'fico_range_high',
'fico_range_low', 'funded_amnt', 'home_ownership','inq_last_6mths','issue_d', 'loan_amnt', 
'loan_status', 'open_acc', 'pub_rec', 'pub_rec_bankruptcies', 'purpose', 'revol_bal', 'revol_util', 'term',
'title', 'total_acc', 'verification_status']

# %%
# remaining features to be dropped after intial feature engineering exercise

drop_list = [col for col in accepted_loans2.columns if col not in keep_list]
print(drop_list)
# Out:
# ['id', 'funded_amnt_inv', 'int_rate', 'installment', 'grade', 'sub_grade', 'pymnt_plan', 'url', 'zip_code', 'addr_state', 'earliest_cr_line', 'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt', 'last_credit_pull_d', 'last_fico_range_high', 'last_fico_range_low', 'policy_code', 'tot_coll_amt', 'tot_cur_bal', 'total_rev_hi_lim', 'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util', 'chargeoff_within_12_mths', 'mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl', 'mort_acc', 'mths_since_recent_bc', 'mths_since_recent_inq', 'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl', 'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl', 'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats', 'num_tl_120dpd_2m', 'num_tl_30dpd', 'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'p
# ...

# %% [markdown]
# Based on the data shape, after feature engineering exercise, the columns are reduced from 93 to 27.

# %%
accepted_loans3 = accepted_loans2.drop(labels=drop_list, axis=1)
accepted_loans3.shape
# Out:
# (1348059, 27)

# %% [markdown]
# #### DATA PREPROCESSING 3: CHECKING FOR MULTICOLLINEARITY

# %%
# setting the style of the visualization
sns.set(style="dark")

# creating a covariance matrix
corr = accepted_loans3.corr()

# setting up the matplotlib figure
f, ax = plt.subplots(figsize=(15,11))

# generating a custom diverging colormap
cmap = sns.diverging_palette(225, 12, as_cmap=True)

# drawing the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, cmap=cmap, center=0, square=True, linewidths=.4, cbar_kws={"shrink": .5}, annot=True);

# %%
# dropping columns with collinearity
# FICO will be dropped averaging 

accepted_loans3.drop(['loan_amnt', 'open_acc', 'pub_rec'], axis=1, inplace=True)

# %%
accepted_loans3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1348059 entries, 0 to 2260697
# Data columns (total 24 columns):
# funded_amnt                   1348059 non-null float64
# term                          1348059 non-null object
# emp_title                     1262115 non-null object
# emp_length                    1269514 non-null object
# home_ownership                1348059 non-null object
# annual_inc                    1348055 non-null float64
# verification_status           1348059 non-null object
# issue_d                       1348059 non-null object
# loan_status                   1348059 non-null object
# purpose                       1348059 non-null object
# title                         1331398 non-null object
# dti                           1347685 non-null float64
# delinq_2yrs                   1348030 non-null float64
# fico_range_low                1348059 non-null float64
# fico_range_high               1348059 non-null float64
# ...

# %% [markdown]
# #### DATA PREPROCESSING 4: REDUCING MEMORY LOADING

# %%
# deleting original dataframe for conserving memory

del accepted_loans
del accepted_loans_null

# %%
# creating new csv so don't have to load large dataset every time
# df.to_csv('loans_smaller_with_current.csv', index=False)

accepted_loans3 = pd.read_csv('loans_smaller_with_current.csv', low_memory=False)
accepted_loans3.drop('Unnamed: 0', axis=1, inplace=True)
accepted_loans3.head()
# Out:
#    funded_amnt        term                    emp_title emp_length  \
# 0       3600.0   36 months                      leadman  10+ years
# 1      24700.0   36 months                     Engineer  10+ years
# 2      20000.0   60 months                 truck driver  10+ years
# 3      35000.0   60 months  Information Systems Officer  10+ years
# 4      10400.0   60 months          Contract Specialist    3 years
#
#   home_ownership  annual_inc verification_status   issue_d loan_status  \
# 0       MORTGAGE     55000.0        Not Verified  Dec-2015  Fully Paid
# 1       MORTGAGE     65000.0        Not Verified  Dec-2015  Fully Paid
# 2       MORTGAGE     63000.0        Not Verified  Dec-2015  Fully Paid
# 3       MORTGAGE    110000.0     Source Verified  Dec-2015     Current
# 4       MORTGAGE    104433.0     Source Verified  Dec-2015  Fully Paid
#
#               purpose          ...          fico_range_high inq_last_6mths  \
# ...

# %% [markdown]
# #### DATA PREPROCESSING 4: NUMERICAL DATA SCRUBBING

# %%
# checking the type of numerical and categorical data in the updated datasets

accepted_loans3.columns.groupby(accepted_loans3.dtypes)
# Out:
# {dtype('float64'): Index(['funded_amnt', 'annual_inc', 'dti', 'delinq_2yrs', 'fico_range_low',
#         'fico_range_high', 'inq_last_6mths', 'revol_bal', 'revol_util',
#         'total_acc', 'collections_12_mths_ex_med', 'acc_now_delinq',
#         'delinq_amnt', 'pub_rec_bankruptcies'],
#        dtype='object'),
#  dtype('O'): Index(['term', 'emp_title', 'emp_length', 'home_ownership',
#         'verification_status', 'issue_d', 'loan_status', 'purpose', 'title',
#         'addr_state', 'earliest_cr_line', 'application_type'],
#        dtype='object')}

# %%
# checking the numerical dataset

accepted_loans3.describe()
# Out:
#         funded_amnt    annual_inc           dti   delinq_2yrs  fico_range_low  \
# count  2.226376e+06  2.226372e+06  2.224703e+06  2.226347e+06    2.226376e+06
# mean   1.500875e+04  7.798697e+04  1.880361e+01  3.058185e-01    6.986865e+02
# std    9.175869e+03  1.130954e+05  1.412853e+01  8.651447e-01    3.305700e+01
# min    5.000000e+02  0.000000e+00 -1.000000e+00  0.000000e+00    6.100000e+02
# 25%    8.000000e+03  4.600000e+04  1.189000e+01  0.000000e+00    6.750000e+02
# 50%    1.280000e+04  6.500000e+04  1.782000e+01  0.000000e+00    6.900000e+02
# 75%    2.000000e+04  9.300000e+04  2.447000e+01  0.000000e+00    7.150000e+02
# max    4.000000e+04  1.100000e+08  9.990000e+02  5.800000e+01    8.450000e+02
#
#        fico_range_high  inq_last_6mths     revol_bal    revol_util  \
# count     2.226376e+06    2.226346e+06  2.226376e+06  2.224612e+06
# mean      7.026867e+02    5.763507e-01  1.667653e+04  5.033478e+01
# ...

# %%
# checking the numerical dataset

accepted_loans3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2226376 entries, 0 to 2226375
# Data columns (total 26 columns):
# funded_amnt                   float64
# term                          object
# emp_title                     object
# emp_length                    object
# home_ownership                object
# annual_inc                    float64
# verification_status           object
# issue_d                       object
# loan_status                   object
# purpose                       object
# title                         object
# addr_state                    object
# dti                           float64
# delinq_2yrs                   float64
# earliest_cr_line              object
# fico_range_low                float64
# fico_range_high               float64
# inq_last_6mths                float64
# revol_bal                     float64
# revol_util                    float64
# total_acc                     float64
# collections_12_mths_ex_med    float64
# ...

# %%
# checking for nulls in numerical data

accepted_loans3.isna().sum()/len(accepted_loans3)
# Out:
# funded_amnt                   0.000000
# term                          0.000000
# emp_title                     0.073558
# emp_length                    0.064686
# home_ownership                0.000000
# annual_inc                    0.000002
# verification_status           0.000000
# issue_d                       0.000000
# loan_status                   0.000000
# purpose                       0.000000
# title                         0.010273
# addr_state                    0.000000
# dti                           0.000751
# delinq_2yrs                   0.000013
# earliest_cr_line              0.000013
# fico_range_low                0.000000
# fico_range_high               0.000000
# inq_last_6mths                0.000013
# revol_bal                     0.000000
# revol_util                    0.000792
# total_acc                     0.000013
# collections_12_mths_ex_med    0.000065
# application_type              0.000000
# acc_now_delinq                0.000013
# ...

# %%
# there are only a small amounts missing data in this updated dataset, will drop null values.

accepted_loans3.dropna(inplace=True)

# %%
accepted_loans3.describe().T
# Out:
#                                 count          mean            std    min  \
# funded_amnt                 2039194.0  15202.560019    9199.597899  500.0
# annual_inc                  2039194.0  79899.335417  116295.217700    0.0
# dti                         2039194.0     18.569637      11.361224   -1.0
# delinq_2yrs                 2039194.0      0.310186       0.872691    0.0
# fico_range_low              2039194.0    698.495452      32.754536  640.0
# fico_range_high             2039194.0    702.495616      32.755271  644.0
# inq_last_6mths              2039194.0      0.577848       0.883231    0.0
# revol_bal                   2039194.0  16907.607047   23046.780676    0.0
# revol_util                  2039194.0     50.651338      24.650632    0.0
# total_acc                   2039194.0     24.341176      12.005532    1.0
# collections_12_mths_ex_med  2039194.0      0.018065       0.150039    0.0
# acc_now_delinq              2039194.0      0.004196       0.070126    0.0
# ...

# %% [markdown]
# #### DATA PREPROCESSING 5: CATEGORICAL DATA SCRUBBING

# %%
categorical_df = accepted_loans3[['emp_title', 'emp_length', 'home_ownership', 'verification_status', 'issue_d', 
                                  'loan_status', 'purpose', 'title', 'application_type']]
categorical_df.head()
# Out:
#                      emp_title emp_length home_ownership verification_status  \
# 0                      leadman  10+ years       MORTGAGE        Not Verified
# 1                     Engineer  10+ years       MORTGAGE        Not Verified
# 3  Information Systems Officer  10+ years       MORTGAGE     Source Verified
# 4          Contract Specialist    3 years       MORTGAGE     Source Verified
# 5         Veterinary Tecnician    4 years           RENT     Source Verified
#
#     issue_d loan_status             purpose               title  \
# 0  Dec-2015  Fully Paid  debt_consolidation  Debt consolidation
# 1  Dec-2015  Fully Paid      small_business            Business
# 3  Dec-2015     Current  debt_consolidation  Debt consolidation
# 4  Dec-2015  Fully Paid      major_purchase      Major purchase
# 5  Dec-2015  Fully Paid  debt_consolidation  Debt consolidation
#
#   application_type
# 0       Individual
# 1       Individual
# 3       Individual
# 4       Individual
# ...

# %%
# the employee title seems to have some nulls and a lot of values in general; it would cause high dimensionality after getting dummy variables
accepted_loans3.emp_title.nunique()
# Out:
# 503379

# %%
accepted_loans3.emp_length.value_counts(dropna=False)
# Out:
# 10+ years    725052
# 2 years      197799
# 3 years      175280
# < 1 year     173732
# 1 year       143178
# 5 years      135300
# 4 years      132425
# 6 years       99672
# 7 years       90223
# 8 years       89264
# 9 years       77269
# Name: emp_length, dtype: int64

# %%
# converting these to numerical data and make the NaN values equal to 0 and < 1 equal to 0.75

accepted_loans3.emp_length.replace(to_replace='10+ years', value='10 years', inplace=True)
accepted_loans3.emp_length.replace(to_replace='< 1 year', value='0.75 years', inplace=True)
accepted_loans3.emp_length.fillna('0 years', inplace=True)

# %%
accepted_loans3.home_ownership.value_counts(dropna=False)
# Out:
# MORTGAGE    1011061
# RENT         813824
# OWN          213373
# ANY             721
# OTHER           172
# NONE             43
# Name: home_ownership, dtype: int64

# %%
# Combining ANY and NONE with OTHER
accepted_loans3.home_ownership.replace(['ANY', 'NONE'], 'OTHER', inplace=True)
accepted_loans3.home_ownership.value_counts(dropna=False)
# Out:
# MORTGAGE    1011061
# RENT         813824
# OWN          213373
# OTHER           936
# Name: home_ownership, dtype: int64

# %%
accepted_loans3.issue_d.value_counts()
# Out:
# Mar-2016    52817
# Oct-2015    45406
# Jul-2015    43233
# May-2018    41211
# Dec-2015    41016
# Aug-2018    40030
# Aug-2017    39272
# Jul-2018    38693
# Oct-2018    38265
# Apr-2018    38151
# Nov-2017    37562
# Jun-2018    37022
# Oct-2014    36567
# Jul-2017    35784
# Sep-2017    35274
# Nov-2015    34955
# Jun-2017    34856
# Nov-2018    34673
# May-2017    34281
# Mar-2018    34175
# Oct-2017    33991
# Dec-2017    33794
# Mar-2017    33668
# Apr-2015    33477
# Feb-2016    33455
# Sep-2018    33406
# Aug-2015    33324
# Jan-2015    33151
# Dec-2018    33061
# Dec-2016    32598
#             ...
# Mar-2010      761
# Feb-2010      627
# Nov-2009      590
# Jan-2010      578
# Dec-2009      569
# Oct-2009      562
# Sep-2009      495
# Aug-2009      435
# Jul-2009      395
# Jun-2009      391
# May-2009      343
# Apr-2009      321
# Mar-2009      315
# Feb-2009      294
# Jan-2009      258
# Dec-2008      244
# Apr-2008      239
# Mar-2008      199
# Nov-2008      199
# ...

# %%
accepted_loans3.title.nunique()
# Out:
# 58504

# %%
# dropping titles 
accepted_loans3.drop('title', axis=1, inplace=True)

# %%
accepted_loans3.columns.groupby(accepted_loans3.dtypes)
# Out:
# {dtype('float64'): Index(['funded_amnt', 'annual_inc', 'dti', 'delinq_2yrs', 'fico_range_low',
#         'fico_range_high', 'inq_last_6mths', 'revol_bal', 'revol_util',
#         'total_acc', 'collections_12_mths_ex_med', 'acc_now_delinq',
#         'delinq_amnt', 'pub_rec_bankruptcies'],
#        dtype='object'),
#  dtype('O'): Index(['term', 'emp_title', 'emp_length', 'home_ownership',
#         'verification_status', 'issue_d', 'loan_status', 'purpose',
#         'addr_state', 'earliest_cr_line', 'application_type'],
#        dtype='object')}

# %%
categorical_df = accepted_loans3[['home_ownership', 'verification_status', 'loan_status', 'purpose', 'application_type']]

# %%
fig = plt.figure(figsize=(15,12))
ax1 = plt.subplot(332)
sns.countplot(categorical_df['home_ownership'])
ax2 = plt.subplot(333)
sns.countplot(categorical_df['verification_status'])
ax3 = plt.subplot(334)
sns.countplot(categorical_df['loan_status'])
ax4 = plt.subplot(335)
sns.countplot(categorical_df['purpose'])
ax5 = plt.subplot(337)
sns.countplot(categorical_df['application_type'])

plt.tight_layout()
plt.show()

# %% [markdown]
# #### DATA PREPROCESSING 5: FINAL PROCESSING FOR AVERAGING, LOG TRANSFORMING AND OTHERS

# %%
drop_list2 = ['delinq_2yrs', 'inq_last_6mths', 'collections_12_mths_ex_med', 'acc_now_delinq', 'delinq_amnt', 'pub_rec_bankruptcies']

# %%
current_loans = accepted_loans3[accepted_loans3['loan_status']=='Current']

# %%
# dropping from curent loan status
past_loans = accepted_loans3.drop(current_loans.index)
past_loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1244999 entries, 0 to 2226374
# Data columns (total 25 columns):
# funded_amnt                   1244999 non-null float64
# term                          1244999 non-null object
# emp_title                     1244999 non-null object
# emp_length                    1244999 non-null object
# home_ownership                1244999 non-null object
# annual_inc                    1244999 non-null float64
# verification_status           1244999 non-null object
# issue_d                       1244999 non-null object
# loan_status                   1244999 non-null object
# purpose                       1244999 non-null object
# addr_state                    1244999 non-null object
# dti                           1244999 non-null float64
# delinq_2yrs                   1244999 non-null float64
# earliest_cr_line              1244999 non-null object
# fico_range_low                1244999 non-null float64
# ...

# %%
accepted_loans3.drop(labels=drop_list2, axis=1, inplace=True)

# %% [markdown]
# ### FICO SCORE

# %%
accepted_loans3['fico_score'] = 0.5*accepted_loans3.fico_range_high + 0.5*accepted_loans3.fico_range_low
accepted_loans3 = accepted_loans3.drop(['fico_range_high', 'fico_range_low'], axis=1)

# %% [markdown]
# ### DTI

# %%
len(accepted_loans3[accepted_loans3['dti']>100])
# Out:
# 1192

# %%
# Since this is a very small amount of the dataset, we can drop these rows.
accepted_loans3 = accepted_loans3.drop(accepted_loans3[accepted_loans3['dti']>100].index)

# %% [markdown]
# ### LOG TRANSFORM

# %%
accepted_loans3['annual_inc_log'] = np.log(accepted_loans3.annual_inc)
accepted_loans3['total_acc_log'] = np.log(accepted_loans3.total_acc)

# %% [markdown]
# ![Data%20Exploration2.jpg](https://raw.githubusercontent.com/andrewwongls/dsc-4-final-project-online-ds-sp-000/master/Data%20Exploration2.jpg)

# %% [markdown]
# ## PART 3 EXPLORING THE LENDING CLUB DATASET

# %% [markdown]
# I had an initial go at exploring the LendingClub dataset in Part 1. With the intensive data scrubbing and feature engineering completed, I ready to delve a bit more deeper for me to get intimate with the dataset. This will allow me to form a view or multiple views of LendingClub and its peripheral entities such as investors and borrowers profile, their operating model, etc.

# %% [markdown]
# ### LOAN STATUS AND ADDRESS STATES

# %% [markdown]
# The standout states are California, Texas and New York, with California being one of the largest state, population, and economy in the US, naturally there will be more borrowers in California.

# %%
# exploring the address states with loan statues of charged off, current, and fully paid.

address_loan = ['addr_state', 'loan_status']

cm = sns.light_palette("red", as_cmap=True)
pd.crosstab(accepted_loans3[address_loan[0]], accepted_loans3[address_loan[1]]).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_4132888c_b5c6_11e9_8e7d_c0b6f9cf9df5row0_col0 {
#             background-color:  #ffe2e2;
#         }    #T_4132888c_b5c6_11e9_8e7d_c0b6f9cf9df5row0_col1 {
#             background-color:  #ffe2e2;
#         }    #T_4132888c_b5c6_11e9_8e7d_c0b6f9cf9df5row0_col2 {
#             background-color:  #ffe2e2;
#         }    #T_4132888c_b5c6_11e9_8e7d_c0b6f9cf9df5row1_col0 {
#             background-color:  #ffcfcf;
#         }    #T_4132888c_b5c6_11e9_8e7d_c0b6f9cf9df5row1_col1 {
#             background-color:  #ffd2d2;
#         }    #T_4132888c_b5c6_11e9_8e7d_c0b6f9cf9df5row1_col2 {
#             background-color:  #ffd3d3;
#         }    #T_4132888c_b5c6_11e9_8e7d_c0b6f9cf9df5row2_col0 {
#             background-color:  #ffd8d8;
#         }    #T_4132888c_b5c6_11e9_8e7d_c0b6f9cf9df5row2_col1 {
#             background-color:  #ffd9d9;
#         }    #T_4132888c_b5c6_11e9_8e7d_c0b6f9cf9df5row2_col2 {
#             background-color:  #ffdcdc;
# ...

# %% [markdown]
# ### LOAN STATUS AND BORROWERS' STATED PURPOSE FOR THE LOAN

# %% [markdown]
# If the stated purpose of the borrowers' purpose is accurate, this will one of the more interesting data points.
#
# The largest stated purpose is debt consolidation. This is one of the most popular and advertised product on LendingClub. The LendingClub's customer value propositions are:
# 1. Instead of dealing with multiple bills, a borrowers can pay them off all at once.
# 2. With an affordable fixed rate, borrowers monthly payment never increases.
# 3. Eliminate high credit card fees and improve borrowers' credit score with a fixed-rate loan.
#
# If the debt consolidation is being used wisely (i.e. paying down debt, rather than getting more debt), then it is a good product for the borrowers.
#
# The next largest stated purpose is paying down credit cards debt. LendingClub's customer value proposition for a personal loan to pay down credit card debt is based on the fact that credit cards interest are very high and there is interest on interest as well. The interest paid on credit cards is often expressed as the Annual Percentage Rate, which considers the cost of interest as well as other costs associated with credit. Most credit card companies add unpaid interest to the principal balance, and therefore do not separate between interest you owe them and the money you borrowed to make a purchase. So, even if the stated APR on your credit card is low, what you ultimately pay in interest could be much higher.
#
# The largest two purposes can be considered as a de-leveraging strategies, it is about paying back what is due.
#
# The next two stated loan purposes are more aspirational. For example, for home improvement (i.e. make a better lifestyle, and increase the house capital value), and major purchase most likely to be car (i.e. needed for work transportation, etc).

# %%
# exploring the borrowers' stated purpose of using the loan and loan status

purpose_loan= ['purpose', 'loan_status']
cm = sns.light_palette("red", as_cmap=True)
pd.crosstab(accepted_loans3[purpose_loan[0]], accepted_loans3[purpose_loan[1]]).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_418a454a_b5c6_11e9_97d0_c0b6f9cf9df5row0_col0 {
#             background-color:  #ffe3e3;
#         }    #T_418a454a_b5c6_11e9_97d0_c0b6f9cf9df5row0_col1 {
#             background-color:  #ffe2e2;
#         }    #T_418a454a_b5c6_11e9_97d0_c0b6f9cf9df5row0_col2 {
#             background-color:  #ffe1e1;
#         }    #T_418a454a_b5c6_11e9_97d0_c0b6f9cf9df5row1_col0 {
#             background-color:  #ffa1a1;
#         }    #T_418a454a_b5c6_11e9_97d0_c0b6f9cf9df5row1_col1 {
#             background-color:  #ff7e7e;
#         }    #T_418a454a_b5c6_11e9_97d0_c0b6f9cf9df5row1_col2 {
#             background-color:  #ff8b8b;
#         }    #T_418a454a_b5c6_11e9_97d0_c0b6f9cf9df5row2_col0 {
#             background-color:  #ff0000;
#         }    #T_418a454a_b5c6_11e9_97d0_c0b6f9cf9df5row2_col1 {
#             background-color:  #ff0000;
#         }    #T_418a454a_b5c6_11e9_97d0_c0b6f9cf9df5row2_col2 {
#             background-color:  #ff0000;
# ...

# %% [markdown]
# ### LOAN AMOUNT AND APPLICATION TYPE - INDIVIDUALS OR JOINT

# %% [markdown]
# Here are some of the interesting statistics:
# 1. Joint applications are popular for building small business and purchasing house. This is likely that case that partners have joint commitment to start a business or build a dream home. Also it is interesting to note that the amount for both purposes are higher than other purposes.
# 2. In sharp contrast, wedding and educational purposes are solely individuals endeavor. The logic says for educational purpose, it is rightly so because it is often an individual's aspiration and goal in life. As for wedding, the sole application is unclear without further information.
# 3. Debt consolidation and paying down credit card debt exhibit almost similar patterns in the violin plot. This shows some close resemblance of borrowers' profile and loan purpose.

# %%
# Now will start exploring the Purpose variable
print("Purposes Description by Count: ")
print(pd.crosstab(accepted_loans3.purpose, accepted_loans3.application_type))

plt.figure(figsize = (12,8))

plt.subplot(211)
g = sns.countplot(x="purpose",data=accepted_loans3,
                  palette='Set2')
g.set_xticklabels(g.get_xticklabels(),rotation=45)
g.set_title("Application Type - Loan Amount", fontsize=20)
g.set_xlabel("", fontsize=15)
g.set_ylabel("Loan Amount", fontsize=15)

plt.subplot(212)
g1 = sns.violinplot(x="purpose",y="funded_amnt",data=accepted_loans3,
               hue="application_type", split=True)
g1.set_xticklabels(g1.get_xticklabels(),rotation=45)
g1.set_title("Application Type - Loan Amount", fontsize=20)
g1.set_xlabel("", fontsize=15)
g1.set_ylabel("Loan Amount", fontsize=15)

plt.subplots_adjust(wspace = 0.2, hspace = 0.8,top = 0.9)
plt.show()
# Out:
# Purposes Description by Count:
# application_type    Individual  Joint App
# purpose
# car                      20801        915
# credit_card             448929      18601
# debt_consolidation     1098924      57646
# educational                336          0
# home_improvement        125591       7838
# house                    12109        481
# major_purchase           43492       2016
# medical                  22266       1711
# moving                   13192        652
# other                   118015       5568
# renewable_energy          1233         61
# small_business           20703        888
# vacation                 13273        507
# wedding                   2253          1

# %% [markdown]
# ### LOAN STATUS AND HOME OWNERSHIP

# %% [markdown]
# There is this very unique psychology makeup of homeowner - they tends to be more settled, with children, and better in making longer term decision-making. These are anecdote accounts, however there are certain truth to it.
#
# However, here the data does not seem to project much patterns.
#
# A further analysis based on percentage breakdown provides a bit context. The percentage charged off for mortgage, own and rent are as follow:
# 1. Mortgage - 10%
# 2. Own - 12&
# 3. Rent - 13%
#
# The percentage calculations shown that for borrowers who rent have slightly higher charged off percentage, however the with only slight margin.

# %%
loan_home = ['loan_status', 'home_ownership']

cm = sns.light_palette("red", as_cmap=True)
pd.crosstab(accepted_loans3[loan_home[0]], accepted_loans3[loan_home[1]]).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_4bee36ec_b5c6_11e9_9320_c0b6f9cf9df5row0_col0 {
#             background-color:  #ffe5e5;
#         }    #T_4bee36ec_b5c6_11e9_9320_c0b6f9cf9df5row0_col1 {
#             background-color:  #ffe5e5;
#         }    #T_4bee36ec_b5c6_11e9_9320_c0b6f9cf9df5row0_col2 {
#             background-color:  #ffe5e5;
#         }    #T_4bee36ec_b5c6_11e9_9320_c0b6f9cf9df5row0_col3 {
#             background-color:  #ffe5e5;
#         }    #T_4bee36ec_b5c6_11e9_9320_c0b6f9cf9df5row1_col0 {
#             background-color:  #ff4444;
#         }    #T_4bee36ec_b5c6_11e9_9320_c0b6f9cf9df5row1_col1 {
#             background-color:  #ff0000;
#         }    #T_4bee36ec_b5c6_11e9_9320_c0b6f9cf9df5row1_col2 {
#             background-color:  #ff2d2d;
#         }    #T_4bee36ec_b5c6_11e9_9320_c0b6f9cf9df5row1_col3 {
#             background-color:  #ff3b3b;
#         }    #T_4bee36ec_b5c6_11e9_9320_c0b6f9cf9df5row2_col0 {
#             background-color:  #ff0000;
# ...

# %% [markdown]
# ### LOAN STATUS AND LOAN VERIFICATION STATUS

# %% [markdown]
# This is part of the filtering/grading process of LendingClub.
#
# I did a quick percentage charged off calculation for not verified, source verified, and verified, the results are counter-intuitive as follow:
# 1. Not verified = 8% charged off
# 2. Source verified = 12% charged off
# 3. Verified = 15% charged off
#
# I would expect with verification, the percentage charged off (aka bad loan) will be lower than those not being verified. This is perhaps one area LendingClub can improve?

# %%
# exploring for any patterns between verification status and loan status
# according to LendingClub's data dictionary - verification status = Indicates if the co-borrowers' joint income was verified by LC, 
# not verified, or if the income source was verified

loan_verification = ['loan_status', 'verification_status']
cm = sns.light_palette("red", as_cmap=True)

pd.crosstab(accepted_loans3[loan_verification[0]], accepted_loans3[loan_verification[1]]).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_4c4d9400_b5c6_11e9_a106_c0b6f9cf9df5row0_col0 {
#             background-color:  #ffe5e5;
#         }    #T_4c4d9400_b5c6_11e9_a106_c0b6f9cf9df5row0_col1 {
#             background-color:  #ffe5e5;
#         }    #T_4c4d9400_b5c6_11e9_a106_c0b6f9cf9df5row0_col2 {
#             background-color:  #ffe5e5;
#         }    #T_4c4d9400_b5c6_11e9_a106_c0b6f9cf9df5row1_col0 {
#             background-color:  #ff2020;
#         }    #T_4c4d9400_b5c6_11e9_a106_c0b6f9cf9df5row1_col1 {
#             background-color:  #ff3131;
#         }    #T_4c4d9400_b5c6_11e9_a106_c0b6f9cf9df5row1_col2 {
#             background-color:  #ff8080;
#         }    #T_4c4d9400_b5c6_11e9_a106_c0b6f9cf9df5row2_col0 {
#             background-color:  #ff0000;
#         }    #T_4c4d9400_b5c6_11e9_a106_c0b6f9cf9df5row2_col1 {
#             background-color:  #ff0000;
#         }    #T_4c4d9400_b5c6_11e9_a106_c0b6f9cf9df5row2_col2 {
#             background-color:  #ff0000;
# ...

# %% [markdown]
# ### LOAN STATUS AND LOAN APPLICATION TYPES

# %% [markdown]
# A quick percentage charged off calculation revealed the following:
# 1. Individual application - 12%
# 2. Joint applications - 5%
#
# It seems like the psychological logic kicks in - if there is another party as part of the loan, there is more accountability in place because there is always another person who will be doing the check-and-balance. On top of it, when there is a joint application, typically the financial risk is shared, therefore the charged off percentage will be lower in joint application.

# %%
# exploring any patterns between loan application type and loan status 

loan_application = ['loan_status', 'application_type']
cm = sns.light_palette("red", as_cmap=True)
pd.crosstab(accepted_loans3[loan_application[0]], accepted_loans3[loan_application[1]]).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_4c9d4250_b5c6_11e9_99a3_c0b6f9cf9df5row0_col0 {
#             background-color:  #ffe5e5;
#         }    #T_4c9d4250_b5c6_11e9_99a3_c0b6f9cf9df5row0_col1 {
#             background-color:  #ffe5e5;
#         }    #T_4c9d4250_b5c6_11e9_99a3_c0b6f9cf9df5row1_col0 {
#             background-color:  #ff5252;
#         }    #T_4c9d4250_b5c6_11e9_99a3_c0b6f9cf9df5row1_col1 {
#             background-color:  #ff0000;
#         }    #T_4c9d4250_b5c6_11e9_99a3_c0b6f9cf9df5row2_col0 {
#             background-color:  #ff0000;
#         }    #T_4c9d4250_b5c6_11e9_99a3_c0b6f9cf9df5row2_col1 {
#             background-color:  #ffc2c2;
#         }</style>
# <table id="T_4c9d4250_b5c6_11e9_99a3_c0b6f9cf9df5" >
# <thead>    <tr>
#         <th class="index_name level0" >application_type</th>
#         <th class="col_heading level0 col0" >Individual</th>
#         <th class="col_heading level0 col1" >Joint App</th>
#     </tr>    <tr>
# ...

# %% [markdown]
# ### HOME OWNERSHIP AND LOAN APPLICATION TYPES

# %% [markdown]
# There is no clear patterns between home ownership and loan application types.

# %%
plt.figure(figsize = (10,6))

g = sns.violinplot(x="home_ownership",y="funded_amnt",data=accepted_loans3,
               kind="violin",
               split=True,palette="hls",
               hue="application_type")
g.set_title("Homer Ownership - Loan Distribuition", fontsize=20)
g.set_xlabel("", fontsize=15)
g.set_ylabel("Loan Amount", fontsize=15)

plt.show()

# %% [markdown]
# ### FUNDED AMOUNT
# LendingClub's Data Dictionary:
# The total amount committed to that loan at that point in time.
#
# There is no counter-intuitive data here - there are more loans in small amounts as compared to higher amounts, with most loans revolves around 10,000 dollars. And, just a small percentage around the 35,000 dollar.

# %%
#I will start looking the loan_amnt column
plt.figure(figsize=(12,6))

plt.subplot(121)
g = sns.distplot(accepted_loans3["funded_amnt"])
g.set_xlabel("", fontsize=12)
g.set_ylabel("Frequency Dist", fontsize=12)
g.set_title("Frequency Distribuition", fontsize=20)

plt.subplot(122)
g1 = sns.violinplot(y="funded_amnt", data=accepted_loans3, 
               inner="quartile", palette="hls")
g1.set_xlabel("", fontsize=12)
g1.set_ylabel("Amount Dist", fontsize=12)
g1.set_title("Amount Distribuition", fontsize=20)

plt.show()

# %% [markdown]
# ### TERMS
# LendingClub's Data Dictionary:
# The number of payments on the loan. Values are in months and can be either 36 or 60.
#
# A large count in the shorter loan period, roughly around 70% of the loan. This correlates to the most popular stated loan purpose i.e. debt consolidation and credit card repayment.

# %%
accepted_loans3['term'].value_counts(dropna=False)
# Out:
#  36 months    1443130
#  60 months     594872
# Name: term, dtype: int64

# %%
accepted_loans3['term'].value_counts(normalize=True)
# Out:
#  36 months    0.70811
#  60 months    0.29189
# Name: term, dtype: float64

# %% [markdown]
# ### EMPLOYMENT LENGTH
# LendingClub's Data Dictionary:
# Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10 means ten or more years.

# %%
accepted_loans3['emp_length'].value_counts(dropna=False).sort_index()
# Out:
# 0.75 years    173354
# 1 year        143078
# 10 years      724851
# 2 years       197652
# 3 years       175163
# 4 years       132360
# 5 years       135239
# 6 years        99635
# 7 years        90187
# 8 years        89237
# 9 years        77246
# Name: emp_length, dtype: int64

# %%
# exploring the employment length data to find patterns

print(pd.crosstab(accepted_loans3["emp_length"], accepted_loans3["application_type"]))

fig, ax = plt.subplots(2,1, figsize=(12,10))
g = sns.boxplot(x="emp_length", y="annual_inc", data=accepted_loans3,
              palette="husl",ax=ax[0],
               order=["n/a",'< 1 year','1 year','2 years','3 years','4 years', '5 years',
                      '6 years', '7 years', '8 years','9 years','10+ years'])

z = sns.violinplot(x="emp_length", y="funded_amnt",data=accepted_loans3, 
               palette="husl", ax=ax[1],
               order=["n/a",'< 1 year','1 year','2 years','3 years','4 years', '5 years',
                      '6 years', '7 years', '8 years','9 years','10+ years'])
               
plt.legend(loc='upper left')
plt.show()
# Out:
# application_type  Individual  Joint App
# emp_length
# 0.75 years            153953      19401
# 1 year                137450       5628
# 10 years              692964      31887
# 2 years               189380       8272
# 3 years               167691       7472
# 4 years               126740       5620
# 5 years               129430       5809
# 6 years                95697       3938
# 7 years                86960       3227
# 8 years                86158       3079
# 9 years                74694       2552
# No handles with labels found to put in legend.

# %% [markdown]
# ![Data%20Modelling2.jpg](https://raw.githubusercontent.com/andrewwongls/dsc-4-final-project-online-ds-sp-000/master/Data%20Modelling2.jpg)

# %% [markdown]
# #### SCRUBBING DATA FURTHER FOR MACHINE LEARNING MODELLING
#
# There are different types, and not all data types can be consumed by machine learning. The following are some of the examples:
#
# 1. Binary — either/or, and it is discrete.
# 2. Count — the number of occurrences, and it is discrete.
# 3. Nominal — data grouping without order, and it is discrete.
# 4. Ordinal — data grouping with order, and it is discrete.
# 5. Time — time series component, and it is continuous.
# 6. Interval — positive and/or negative numbers and permanent component, and it is continuous.
# The more data we feed into our machine learning models, the better the models will perform. Of course, I am stating the obvious, the data has to be cleaned. Otherwise, we will faced Garbage In, Garbage Out (GIGO) situation. Here we are concerned with encoding nominal (#3) and ordinal data (#4). A column with nominal data has values that cannot be ordered in any meaningful way. Nominal data is most often one-hot (aka dummy) encoded, but there are many options that might perform better for machine learning. And, some of the options are describe below:
#
# 1. Ordinal — convert string labels to integer values 1 through k. Ordinal.
# 2. Binary — convert each integer to binary digits. Each binary digit gets one column. Some info loss but fewer dimensions. Ordinal.
# 3. BaseN — Ordinal, Binary, or higher encoding. Nominal, ordinal. Doesn’t add much functionality. Probably avoid.
# 4. Hashing — Like OneHot but fewer dimensions, some info loss due to collisions. Nominal, ordinal.
# 5. OneHot — one column for each value to compare vs. all other values. Nominal, ordinal.
#
# I will use pandas one-hot encoding for this purpose. The one hot encoding is a technique that convert categorical values into a 1-dimensional numerical vector. The resulting vector will have only one element equal to 1 and the rest will be 0. The 1 is called Hot and the 0's are Cold.

# %% [markdown]
# #### SET TARGET VARIABLES

# %%
# Dropping rows not in 'Fully Paid' or 'Charged Off'
accepted_loans3 = accepted_loans3.loc[accepted_loans3['loan_status'].isin(['Fully Paid', 'Charged Off','Does not meet the credit policy. Status:Fully Paid',
'Does not meet the credit policy. Status:Charged Off'])]
accepted_loans3.shape
# Out:
# (1244737, 20)

# %%
accepted_loans3['loan_status'].value_counts(normalize=True)
# Out:
# Fully Paid     0.805486
# Charged Off    0.194514
# Name: loan_status, dtype: float64

# %%
# turning target variable into 1's and 0's
accepted_loans3['fully_paid'] = accepted_loans3.loan_status.astype('category').cat.codes
accepted_loans3.drop('loan_status', axis=1, inplace=True)

# %%
accepted_loans3.fully_paid.value_counts(normalize=True)
# Out:
# 1    0.805486
# 0    0.194514
# Name: fully_paid, dtype: float64

# %% [markdown]
# I have troubled calculating 1.2 millions lines, which has caused my local PC to crash. For the purpose of this project, I will reduce the sample size down to 1000 to reduce the PC crash count!
#
# In the next project, my intention is to start using Kaggle Kernel or push to AWS for cloud processing.

# %%
# reducing the processing lines from 2.2 millions to 1000 to avoid further PC harward crashes

X = accepted_loans3.sample(1000).drop('fully_paid', axis=1)
y = accepted_loans3.sample(1000).fully_paid
X = pd.get_dummies(X, drop_first=True)

# %%
X.shape
# Out:
# (1000, 1339)

# %% [markdown]
# #### SPLITTING DATASET IN TRAIN AND TEST SET

# %%
# splitting the data into train and test set ready for machine learning modelling
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4)

# %%
# Check the split of the target variable
y_test.value_counts(normalize=True)
# Out:
# 1    0.78
# 0    0.22
# Name: fully_paid, dtype: float64

# %% [markdown]
# ## BASIC PREDICTIVE MODELLING (BEFORE GOING DEEP)

# %% [markdown]
# In order to help answer the above questions, I will be utilizing the following predictive analytics models:
#
# 1. Logistic Regression
# 2. Random Forest
# 3. XGBoost
# 4. Support Vector Machine

# %% [markdown]
# ### LOGISTIC REGRESSION MODELLING
#
# Regression is a technique used to predict the value of a response (dependent) variables, from one or more predictor (independent) variables, where the variable are numeric.
#
# Linear and Logistic regression are the most basic form of regression which are commonly used. The essential difference between these two is that Logistic regression is used when the dependent variable is binary in nature. In contrast, Linear regression is used when the dependent variable is continuous and nature of the regression line is linear. Linear regression algorithms are used to predict/forecast values but logistic regression is used for classification tasks.
#
# Diagram Logistics Regression: An Illustrated Logistric Regression (Diagram Credit: MachineLearningPlus.com)
#
# ![Logistic%20Regression.PNG](https://raw.githubusercontent.com/andrewwongls/dsc-4-final-project-online-ds-sp-000/master/Logistic%20Regression.PNG)

# %%
# starting the logistic regression
logreg = LogisticRegression()

# training
logreg.fit(X_train, y_train)

# predicting
train_preds = logreg.predict(X_train)
test_preds = logreg.predict(X_test)

# evaluating
train_accuracy_logreg = accuracy_score(y_train, train_preds)
test_accuracy_logreg = accuracy_score(y_test, test_preds)
report_logreg = classification_report(y_test, test_preds)

print("Logistic Regression")
print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++")
print(f"Training Accuracy: {(train_accuracy_logreg * 100):.3}%")
print(f"Test Accuracy:     {(test_accuracy_logreg * 100):.3}%")
# Out:
# Logistic Regression
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Training Accuracy: 82.5%
# Test Accuracy:     77.2%

# %% [markdown]
# #### RANDOM FOREST MODELLING
#
# Random forest spun out of decision tree. It is better than decision tree. Take the analogy of having thousands of thinking machine make predictions for the traffic in the city of Melbourne between 4pm and 7pm. The thousands of thinking machine can make a combination of predictions, it is faster and use the wisdom of the crowd (in this case wisdom of the chips!).
#
# On to the similar analogy of thousands of thinking machine - each decision machine (tree) in the thousands of machine (forest) considers a random subset of features when forming questions and only has access to a random set of the training data points. This rule therefore increases 'a distributed opinion/view' in the forest leading to more robust overall predictions. Henceforth the name ‘random forest.’ When it comes time to make a prediction, the random forest takes an average of all the individual decision tree estimates.
#
# Diagram Random Forest: An Illustrated Random Forest (Diagram Credit: Towards Data Science Medium Blog)

# %% [markdown]
# ![Random%20Forest.PNG](https://raw.githubusercontent.com/andrewwongls/dsc-4-final-project-online-ds-sp-000/master/Random%20Forest.PNG)

# %%
# creating a baseline
forest = RandomForestClassifier()

# %%
# creating Grid              
param_grid = {'n_estimators': [80, 100, 120],
              'criterion': ['gini', 'entropy'],
              'max_features': [5, 7, 9],         
              'max_depth': [5, 8, 10], 
              'min_samples_split': [3, 4, 5]}

# starring the tune random forest
forest_grid_search = GridSearchCV(forest, param_grid, cv=7, n_jobs=-1)

# training the tuned random forest
forest_grid_search.fit(X_train, y_train)

# printing best estimator parameters found during the grid search
print(forest_grid_search.best_params_)
# Out:
# {'criterion': 'gini', 'max_depth': 5, 'max_features': 5, 'min_samples_split': 3, 'n_estimators': 80}

# %%
# instantiating the tuned random forest with the best found parameters
forest = RandomForestClassifier(n_estimators=120, criterion='gini', max_features=9, 
                                max_depth=10, min_samples_split=4, random_state=4)

# training the random forest
forest.fit(X_train, y_train)

# predicting the random forest
train_preds = forest.predict(X_train)
test_preds = forest.predict(X_test)

# evaluating 
train_accuracy_forest = accuracy_score(y_train, train_preds)
test_accuracy_forest = accuracy_score(y_test, test_preds)
report_forest = classification_report(y_test, test_preds)

print("Random Forest")
print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++")
print(f"Training Accuracy: {(train_accuracy_forest * 100):.4}%")
print(f"Test Accuracy:     {(test_accuracy_forest * 100):.4}%")
# Out:
# Random Forest
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Training Accuracy: 82.0%
# Test Accuracy:     78.0%

# %% [markdown]
# #### EXTREME BOOSTING (XGBOOST) MODELLING
#
# The extreme boosting is an ensemble technique where new models are added to correct the errors made by existing models. One by one the new models are added sequentially until no further improvements can be made.
#
# The gradient boosting is an approach where new models are created that predict the residuals or errors of prior models and then added together to make the final prediction. It is called gradient boosting because it uses a gradient descent algorithm to minimize the loss when adding new models. This approach supports both regression and classification predictive modeling problems.
#
# Diagram Extreme Boosting: Illustrated XGBoost (Diagram Credit: Kaggle)

# %% [markdown]
# ![XGBoost.png](https://raw.githubusercontent.com/andrewwongls/dsc-4-final-project-online-ds-sp-000/master/XGBoost.png)

# %%
# creating a baseline
booster = xgb.XGBClassifier()

# %%
# creating the grid
param_grid = {'n_estimators': [100],
              'learning_rate': [0.05, 0.1], 
              'max_depth': [3, 5, 10],
              'colsample_bytree': [0.7, 1],
              'gamma': [0.0, 0.1, 0.2]}

# starting the tuned random forest
booster_grid_search = GridSearchCV(booster, param_grid, scoring='accuracy', cv=3, n_jobs=-1)

# training the tuned random forest
booster_grid_search.fit(X_train, y_train)

# print best estimator parameters found during the grid search
print(booster_grid_search.best_params_)
# Out:
# {'colsample_bytree': 0.7, 'gamma': 0.1, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}

# %%
# starting tuned xgboost
booster = xgb.XGBClassifier(learning_rate=0.1, max_depth=5, n_estimators=100,
                            colsample_bytree=0.7, gamma=0.1, random_state=4)

# training
booster.fit(X_train, y_train)

# predicting
train_preds = booster.predict(X_train)
test_preds = booster.predict(X_test)

# evaluating
train_accuracy_booster = accuracy_score(y_train, train_preds)
test_accuracy_booster = accuracy_score(y_test, test_preds)
report_booster = classification_report(y_test, test_preds)

print("XGBoost")
print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++")
print(f"Training Accuracy: {(train_accuracy_booster * 100):.4}%")
print(f"Test Accuracy:     {(test_accuracy_booster * 100):.4}%")
# Out:
# XGBoost
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Training Accuracy: 97.67%
# Test Accuracy:     77.5%

# %% [markdown]
# #### SUPPORT VECTOR MACHINE MODELLING
#
# Support vectors are data points that are closer to the hyperplane and influence the position and orientation of the hyperplane. Using these support vectors, we maximize the margin of the classifier. Deleting the support vectors will change the position of the hyperplane. These are the points that help us build our SVM.
#
# Diagram Support Vector Machine: An Illustrated SVM (Diagram Credit: Towards Data Science Medium Blog)

# %% [markdown]
# ![SVM.PNG](https://raw.githubusercontent.com/andrewwongls/dsc-4-final-project-online-ds-sp-000/master/SVM.PNG)

# %%
# instantiating Support Vector Classification
svm = svm.SVC(kernel='rbf', random_state=4)

# training
svm.fit(X_train, y_train)

# predicting
train_preds = svm.predict(X_train)
test_preds = svm.predict(X_test)

# evaluating
train_accuracy_svm = accuracy_score(y_train, train_preds)
test_accuracy_svm = accuracy_score(y_test, test_preds)
report_svm = classification_report(y_test, test_preds)

print("Support Vector Machine")
print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++")
print(f"Training Accuracy: {(train_accuracy_svm * 100):.4}%")
print(f"Test Accuracy:     {(test_accuracy_svm * 100):.4}%")
# Out:
# Support Vector Machine
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Training Accuracy: 100.0%
# Test Accuracy:     78.0%

# %% [markdown]
# #### INTERPRETATION OF PERFORMANCE MEASURES: PRECISION, RECALL AND F1 SCORE
#
# I will be running SKLearn Metric to generation classification reporting. The following reporting will be generation, and I'd like provide some explanations of each reporting:
#
# > **Precision Score**
#
# Precision – Accuracy of positive predictions. Precision = TP/(TP + FP)
#
# > **Recall Score**
#
# Recall (aka sensitivity or true positive rate): Fraction of positives That were correctly identified. Recall = TP/(TP+FN)
#
# > **F1 Score**
#
# A helpful metric for comparing two classifiers. F1 Score takes into account precision and the recall. It is created by finding the the harmonic mean of precision and recall. F1 = 2 x (precision x recall)/(precision + recall)
#
# > **Support**
#
# The support is the number of samples of the true response that lie in that class.
#
# > **The Reported Averages**
#
# Micro average (averaging the total true positives, false negatives and false positives)
#
# Macro average (averaging the unweighted mean per label)
#
# Weighted average (averaging the support-weighted mean per label)
#
# Sample average (only for multilabel classification).

# %%
print('Classification Report Logistic Regression: \n', report_logreg)
print('++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++')
print('Classification Report Random Forest: \n', report_forest)
print('++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++') 
print('Classification Report XGBoost: \n', report_booster)
print('++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++')
print('Classification Report SVM: \n', report_svm)
# Out:
# Classification Report Logistic Regression:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        88
#            1       0.78      0.99      0.87       312
#
#     accuracy                           0.77       400
#    macro avg       0.39      0.50      0.44       400
# weighted avg       0.61      0.77      0.68       400
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Classification Report Random Forest:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        88
#            1       0.78      1.00      0.88       312
#
#     accuracy                           0.78       400
#    macro avg       0.39      0.50      0.44       400
# weighted avg       0.61      0.78      0.68       400
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Classification Report XGBoost:
# ...

# %% [markdown]
# Through Random Forest, I have plotted and identified Top 5 relative influence factors (or predictors) of whether a borrowers will default a loan or not. Let's discus a bit more on this matter as it is important for LendingClub to understanding in their product design.
#
#
# > **Annual Income** The self-reported annual income provided by the borrower during registration.
#
# The annual income provides the basis of loan repayment. We haven't run the correlation analysis, however it is safe to say that the higher the annual income, the better a borrower able to repayment the monthly loan payment because there will likely be discretionary percentage.
#
# > **Revolving Balance** Total credit revolving balance.
#
# The revolving balance is the total credit revolving balance with the borrowers. Again, we haven't correlation analysis, however the logic here is that the higher or longer revolving balance, the higher the chance for loan default.
#
# > **Total Account** The total number of credit lines currently in the borrower's credit file.
#
#
# The logic here - the more credit lines the higher the chance of defaults.
#
#
# > **FICO Score** The representation of individual's creditworthiness.
#
# The FICO score is based on external credit assessment, sort of industry standard. Naturally, there is science behind it, which is useful to predict a good borrower from a bad borrower.
#
#
# > **DTI** A ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage and the requested LC loan, divided by the borrower’s self-reported monthly income.
#
#
# The DTI in its long form is debt to loan ratio.

# %%
# plotting the influential factors - based on Random Forest
influential_factors = pd.Series(forest.feature_importances_, index=X.columns)
influential_factors.nlargest(30).sort_values().plot(kind='barh', color='darkgrey', figsize=(10,5))
plt.xlabel('Relative Influential Factors with Random Forest');

# %% [markdown]
# Let's get into the more complicated predictive modeling - Deep Neural Network.
#
# Deep learning is a machine learning technique that teaches computers to learn by example. A deep neural network is a neural network with a certain level of complexity, a neural network with more than two layers. Deep neural networks use sophisticated mathematical modeling to process data in complex ways.
#
# Image credit: https://thedatascientist.com/what-deep-learning-is-and-isnt/
# ![Machine%20and%20Deep%20Learning.JPG](https://raw.githubusercontent.com/andrewwongls/dsc-4-final-project-online-ds-sp-000/master/Machine%20and%20Deep%20Learning.JPG)

# %% [markdown]
# ## DEEP NEURAL NETWORK

# %% [markdown]
# ### MODEL 1: MULTI-LAYER PERCEPTRON NEURAL NETWORK WITH KERAS
#
# Keras provides a high-level API abstraction for developing deep neural network models. There are a large number of core Layer types for standard neural networks.
#
# The Keras Model forms the core of a Keras programme.
#
# A Model is first constructed, then it is compiled. Next, the compiled model is trained and evaluated using their respective training and evaluation datasets. Upon successful evaluation using the relevant metrics, the model is then used for making predictions on previously unseen data samples.
#
# Below is the 5-step life-cycle of a deep learning neural network using the Keras library.
#
# ![Keras%20Model.JPG](https://raw.githubusercontent.com/andrewwongls/dsc-4-final-project-online-ds-sp-000/master/Keras%20Model.JPG)
#
# Some common and useful layer types you can choose from are:
# 1. Dense: Fully connected layer and the most common type of layer used on multi-layer perceptron models.
# 2. Dropout: Apply dropout to the model, setting a fraction of inputs to zero in an effort to reduce over fitting.
# 3. Merge: Combine the inputs from multiple models into a single model.
#
# In Model 1, I starting with a simple dense layering.

# %%
# Model 1 - simple dense layering

input_shape = X_train.shape
model = Sequential()
model.add(Dense(12, kernel_initializer='uniform', activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dense(8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))

model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\computer87543\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 12)                16080
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 104
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 9
# ...
# Total params: 16,193
# Trainable params: 16,193
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model_val = model.fit(X_train, y_train, epochs=5, batch_size=100, validation_data=(X_test, y_test))
# Out:
# WARNING:tensorflow:From C:\Users\computer87543\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 600 samples, validate on 400 samples
# Epoch 1/5
# 600/600 [==============================] - 0s 712us/step - loss: 1.7812 - acc: 0.5933 - val_loss: 1.6969 - val_acc: 0.7800
# Epoch 2/5
# 600/600 [==============================] - 0s 52us/step - loss: 1.4337 - acc: 0.8200 - val_loss: 1.2926 - val_acc: 0.7800
# Epoch 3/5
# 600/600 [==============================] - 0s 53us/step - loss: 0.7275 - acc: 0.8183 - val_loss: 0.7469 - val_acc: 0.5025
# Epoch 4/5
# 600/600 [==============================] - 0s 55us/step - loss: 0.7121 - acc: 0.5583 - val_loss: 0.6442 - val_acc: 0.7800
# Epoch 5/5
# 600/600 [==============================] - 0s 48us/step - loss: 0.6499 - acc: 0.8200 - val_loss: 0.7564 - val_acc: 0.7800

# %%
train_score = model.evaluate(X_train, y_train)
test_score = model.evaluate(X_test, y_test)
print('Train Score:', train_score)
print('Test Score:', test_score)
# Out:
# ...
# 400/400 [==============================] - 0s 25us/step
# Train Score: [0.6217259446779887, 0.8200000007947286]
# Test Score: [0.756449282169342, 0.78]

# %%
model_dict = model_val.history

# %%
plt.clf()

loss_values = model_dict['loss']
val_loss_values = model_dict['val_loss']

epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, 'g', label='Training loss')
plt.plot(epochs, val_loss_values, 'blue', label='Validation loss')

plt.title('Training & validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### MODEL 2: MULTI-LAYER PERCEPTRON NEURAL NETWORK WITH KERAS - WITH DENSER LAYER

# %%
# adding more and larger layers
input_shape = X_train.shape
model2 = Sequential()
model2.add(Dense(34, kernel_initializer='uniform', activation='relu', input_shape=(X_train.shape[1],)))
model2.add(Dense(68, kernel_initializer='uniform', activation='relu'))
model2.add(Dense(68, kernel_initializer='uniform', activation='relu'))
model2.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))

model2.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_4 (Dense)              (None, 34)                45560
# _________________________________________________________________
# dense_5 (Dense)              (None, 68)                2380
# _________________________________________________________________
# dense_6 (Dense)              (None, 68)                4692
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 69
# ...
# Total params: 52,701
# Trainable params: 52,701
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model_val2 = model2.fit(X_train, y_train, epochs=5, batch_size=100, validation_data=(X_test, y_test))
# Out:
# Train on 600 samples, validate on 400 samples
# Epoch 1/5
# 600/600 [==============================] - 0s 682us/step - loss: 1.7269 - acc: 0.7250 - val_loss: 1.4471 - val_acc: 0.7800
# Epoch 2/5
# 600/600 [==============================] - 0s 52us/step - loss: 0.7333 - acc: 0.7383 - val_loss: 0.7235 - val_acc: 0.7750
# Epoch 3/5
# 600/600 [==============================] - 0s 53us/step - loss: 0.5743 - acc: 0.8200 - val_loss: 0.5972 - val_acc: 0.7550
# Epoch 4/5
# 600/600 [==============================] - 0s 55us/step - loss: 0.5768 - acc: 0.8200 - val_loss: 0.5873 - val_acc: 0.7425
# Epoch 5/5
# 600/600 [==============================] - 0s 68us/step - loss: 0.5350 - acc: 0.8000 - val_loss: 0.5906 - val_acc: 0.7775

# %%
train_score2 = model2.evaluate(X_train, y_train)
test_score2 = model2.evaluate(X_test, y_test)
print('Train Score:', train_score2)
print('Test Score:', test_score2)
# Out:
# ...
# 400/400 [==============================] - 0s 30us/step
# Train Score: [0.5063557108243306, 0.8250000007947286]
# Test Score: [0.5905501472949982, 0.7775]

# %%
model_dict2 = model_val2.history

# %%
plt.clf()

loss_values = model_dict2['loss']
val_loss_values = model_dict2['val_loss']

epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, 'g', label='Training loss')
plt.plot(epochs, val_loss_values, 'blue', label='Validation loss')

plt.title('Training & validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.clf()

acc_values = model_dict2['acc'] 
val_acc_values = model_dict2['val_acc']

plt.plot(epochs, acc_values, 'r', label='Training acc')
plt.plot(epochs, val_acc_values, 'blue', label='Validation acc')
plt.title('Training & validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### MODEL 3: MULTI-LAYER PERCEPTRON NEURAL NETWORK WITH KERAS - WITH DROPOUT

# %%
# adding L2 Regularizer and more epochs and dropout layers
input_shape = X_train.shape
model3 = Sequential()
model3.add(Dense(34, kernel_initializer='normal', activation='relu', input_shape=(X_train.shape[1],)))
model3.add(Dense(68, kernel_regularizer=regularizers.l2(0.005), activation='relu'))
model3.add(Dropout(0.3))
model3.add(Dense(68, kernel_regularizer=regularizers.l2(0.005), activation='relu'))
model3.add(Dropout(0.3))
model3.add(Dense(1, kernel_initializer='normal', activation='sigmoid'))

model3.summary()
# Out:
# WARNING:tensorflow:From C:\Users\computer87543\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_8 (Dense)              (None, 34)                45560
# _________________________________________________________________
# dense_9 (Dense)              (None, 68)                2380
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 68)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 68)                4692
# ...

# %%
model3.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model_val3 = model3.fit(X_train, y_train, epochs=5, batch_size=100, validation_data=(X_test, y_test))
# Out:
# Train on 600 samples, validate on 400 samples
# Epoch 1/5
# 600/600 [==============================] - 1s 933us/step - loss: 3.6868 - acc: 0.8017 - val_loss: 4.0481 - val_acc: 0.7800
# Epoch 2/5
# 600/600 [==============================] - 0s 63us/step - loss: 3.4878 - acc: 0.8133 - val_loss: 4.0183 - val_acc: 0.7800
# Epoch 3/5
# 600/600 [==============================] - 0s 61us/step - loss: 3.3688 - acc: 0.8200 - val_loss: 3.9903 - val_acc: 0.7800
# Epoch 4/5
# 600/600 [==============================] - 0s 63us/step - loss: 3.3416 - acc: 0.8200 - val_loss: 3.9641 - val_acc: 0.7800
# Epoch 5/5
# 600/600 [==============================] - 0s 62us/step - loss: 3.3161 - acc: 0.8200 - val_loss: 3.9396 - val_acc: 0.7800

# %%
train_score3 = model3.evaluate(X_train, y_train)
test_score3 = model3.evaluate(X_test, y_test)
print('Train Score:', train_score3)
print('Test Score:', test_score3)
# Out:
# ...
# 400/400 [==============================] - 0s 30us/step
# Train Score: [3.3019232336680093, 0.8200000007947286]
# Test Score: [3.939618606567383, 0.78]

# %%
model_dict3 = model_val3.history

# %%
plt.clf()

loss_values = model_dict3['loss']
val_loss_values = model_dict3['val_loss']

epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, 'g', label='Training loss')
plt.plot(epochs, val_loss_values, 'blue', label='Validation loss')

plt.title('Training & validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## DEEP NEURAL NETWORK (EXPERIMENTAL ONLY!)

# %% [markdown]
# ### MODEL 4: MULTI-LAYER PERCEPTRON NEURAL NETWORK WITH KERAS - STACKED LSTM FOR SEQUENCE CLASSIFICATION

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense
import numpy as np

data_dim = 16
timesteps = 8
num_classes = 10

# expected input data shape: (batch_size, timesteps, data_dim)
input_shape = X_train.shape
model5 = Sequential()
model5.add(LSTM(32, return_sequences=True,
               input_shape=(timesteps, data_dim)))  # returns a sequence of vectors of dimension 32
model5.add(LSTM(32, return_sequences=True))  # returns a sequence of vectors of dimension 32
model5.add(LSTM(32))  # return a single vector of dimension 32
model5.add(Dense(10, activation='softmax'))

model5.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# Generate dummy training data
x_train = np.random.random((1000, timesteps, data_dim))
y_train = np.random.random((1000, num_classes))

# Generate dummy validation data
x_val = np.random.random((100, timesteps, data_dim))
y_val = np.random.random((100, num_classes))

model5.fit(x_train, y_train,
          batch_size=64, epochs=5,
          validation_data=(x_val, y_val))
# Out:
# Train on 1000 samples, validate on 100 samples
# Epoch 1/5
# 1000/1000 [==============================] - 2s 2ms/step - loss: 11.5190 - acc: 0.0960 - val_loss: 11.4858 - val_acc: 0.1300
# Epoch 2/5
# 1000/1000 [==============================] - 0s 198us/step - loss: 11.5175 - acc: 0.1080 - val_loss: 11.4874 - val_acc: 0.0700
# Epoch 3/5
# 1000/1000 [==============================] - 0s 217us/step - loss: 11.5166 - acc: 0.1010 - val_loss: 11.4848 - val_acc: 0.1200
# Epoch 4/5
# 1000/1000 [==============================] - 0s 225us/step - loss: 11.5164 - acc: 0.0990 - val_loss: 11.4853 - val_acc: 0.0900
# Epoch 5/5
# 1000/1000 [==============================] - 0s 235us/step - loss: 11.5159 - acc: 0.1040 - val_loss: 11.4875 - val_acc: 0.0600

# %% [markdown]
# ### MODEL 5: MULTI-LAYER PERCEPTRON NEURAL NETWORK WITH KERAS - STACKED LSTM FOR SEQUENCE CLASSIFICATION - RENDER STATEFUL

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense
import numpy as np

data_dim = 16
timesteps = 8
num_classes = 10
batch_size = 32

# Expected input batch shape: (batch_size, timesteps, data_dim)
# Note that we have to provide the full batch_input_shape since the network is stateful.
# the sample of index i in batch k is the follow-up for the sample i in batch k-1.
model6 = Sequential()
model6.add(LSTM(32, return_sequences=True, stateful=True,
               batch_input_shape=(batch_size, timesteps, data_dim)))
model6.add(LSTM(32, return_sequences=True, stateful=True))
model6.add(LSTM(32, stateful=True))
model6.add(Dense(10, activation='softmax'))

model6.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# Generate dummy training data
x_train = np.random.random((batch_size * 10, timesteps, data_dim))
y_train = np.random.random((batch_size * 10, num_classes))

# Generate dummy validation data
x_val = np.random.random((batch_size * 3, timesteps, data_dim))
y_val = np.random.random((batch_size * 3, num_classes))

model6.fit(x_train, y_train,
          batch_size=batch_size, epochs=5, shuffle=False,
          validation_data=(x_val, y_val))
# Out:
# Train on 320 samples, validate on 96 samples
# Epoch 1/5
# 320/320 [==============================] - 2s 6ms/step - loss: 11.3124 - acc: 0.0781 - val_loss: 11.4673 - val_acc: 0.1354
# Epoch 2/5
# 320/320 [==============================] - 0s 262us/step - loss: 11.3048 - acc: 0.0813 - val_loss: 11.4665 - val_acc: 0.1354
# Epoch 3/5
# 320/320 [==============================] - 0s 281us/step - loss: 11.3034 - acc: 0.0813 - val_loss: 11.4662 - val_acc: 0.1354
# Epoch 4/5
# 320/320 [==============================] - 0s 299us/step - loss: 11.3024 - acc: 0.0844 - val_loss: 11.4661 - val_acc: 0.1354
# Epoch 5/5
# 320/320 [==============================] - 0s 293us/step - loss: 11.3013 - acc: 0.0813 - val_loss: 11.4660 - val_acc: 0.1354

# %% [markdown]
# ![Data%20Interpretation2.jpg](https://raw.githubusercontent.com/andrewwongls/dsc-4-final-project-online-ds-sp-000/master/Data%20Interpretation2.jpg)

# %% [markdown]
# Let's summarize based on what we have produced so far.
#
# > **Predictive Modeling Based on Logistic Regressio, Random Forest, XGBoost, and SVM - Test Accuracy Results**
#
# Logistic Regression: 78.5%
#
# Random Forest      : 78.5%
#
# XGBoost            : 77.2%
#
# SVM                : 78.5%
#
#
# > **Predictive Modeling Based on Deep Neural Network**
#
# Layer 1: 79%
#
# Layer 2: 78%
#
# Layer 3: 79%
#
#
# > **Top 5 Predictors Based on Random Forest Relative Features Importance:**
#
# 1. Annual income
#
# 2. Revolving balance
#
# 3. Total account
#
# 4. FICO score
#
# 5. DTI

# %% [markdown]
# ## MACHINE LEARNING PRODUCT-DRIVEN

# %% [markdown]
# As a LendingClub Product Manager, I would recommend to have a continuous learning-feedback cycle to further improve the predictive capability of machine learning as well as leveraging on human-in-the-loop advantages.
#
# The learning-feedback cycle to improve the predictive capability of machine learning can comes in the form of updating the existing models and the way it sense the world - through constant feeding of updated datasets, as well as new type of datasets.
#
# The learning-feedback cycle to leverage on the human-in-the-loop advantages can comes in the form of (1) training the model (i.e. actively feed datasets to train model to improve the predictive power of a good or bad loan), (2) uncovering algorithm bias, fairness and accountability (i.e. after all LendingClub has social responsibility to protect investors and borrowers financial commitment), and (3) designing forward new services (i.e. the combination of human + DNN (deep neural network), LendingClub can reach faster, deeper on getting into strategic questions/ insights.

# %% [markdown]
# ![ML%20at%20LendingClub.JPG](https://raw.githubusercontent.com/andrewwongls/dsc-4-final-project-online-ds-sp-000/master/ML%20at%20LendingClub.JPG)

# %% [markdown]
# At the start of this project, I have decided to use Design Sprint and Agile Development practices to complement with the OSEMN Data Science workflow. The ultimate goal is to design a brand new way of working as a data scientist and thinking about data science.
#
# > **Design Sprint**
#
# Through Design Sprint, I started to get the worldview of LendingClub - all things from their business model, customer value proposition, borrowers and investors' profile, competitors, and of course the available datasets.This allows me to get into the Problem Space (Day 1 - Map the target problem), and later into Solution Space (Day 2 and 3 - Sketch and decision on solution). The diagram below (Machine Learning Applications) is the outcome of my shifting from Day 1 all the way to Day 2 and 3, and later to Day 4 and 5. I won't go into details of Day 4 and 5. I may write a bit more in Medium Website in the near future.
#
# In the Solution Space, I started to toy with what Machine Learning capabilities that LendingClub can build based on the predictive modeling that I have built (no doubt it is not as simple as that!). Let's take out the technical implementation complexity for now, and imagine the following.
#
# >> **The constellation of machine learning capabilities that LendingClub can leverage on:**
# 1. Self optimizing through large scale processing - this is about being able to optimizing real-time based on new dataset and new factors.
# 2. Predictive systems through evidence based learning - this is about using deep neural network to learn about borrowers' new behaviors and how it affect their Top 5 Predictors (based on random forest) and other predictors.
# 3. Learning human behavior through reinforce learning - this is about being able use different borrowers' personas to predict their behaviors. This is especially useful for LendingClub, if and when, they are moving to a brand new market where there is no existing data.
# 4. Knowledge modeling through knowledge graph - Knowledge Graph is a model of a knowledge domain created by subject-matter experts with the help of intelligent machine learning algorithms. Therefore, this is about leveraging on domain knowledge expert within and outside of LendingClub to build a better repository of knowledge about borrowers' profile and financial risk management.
# 5. Expert system through inferencing - In the field of Machine Learning, inference engine is a component of the system that applies logical rules to the knowledge base to deduce new information. This is about using theoretical and science-based research to improve predictive modeling.
# 6. Adaptive alteration through self-sensing - This is about using trigger-points to sense behavioral changes.
#
#
#
# >> **The constellation of machine learning applications that LendingClub can build:**
# 1. Robo Accountability Auditor - this is about scanning for potential breaches in data privacy, decision bias, and protection against convoluted decision points.
# 2. Dynamic downward rates adjustment for borrowers - this is about whenever there is a positive change in lifestyle/circumstances, borrowers will instantly benefits from a lower borrowing interest rates. This will nudge positive behavior, therefore lowering lending risk.
# 3. Humanizing Financial Recommendation - This is about borrowers being matched dynamically through their location, income, social network, and aspiration (i.e. inferencing through their borrowing purpose). This will create a more personalized, human interactions with borrowers.
# 4. Dynamic  Macroeconomics and Seasonal Product Marketing - There is limit to LendingClub product managers in sensing the environmental factors that impacts both lenders and borrowers. We can help by hooking to Reuters or Bloomberg news to scan for potential black swan (unexpected large-scale negative changes) or positive news.
# 5. Robo Financial Planner for Borrower - LendingClub’s vast array of financial products can be daunting for borrowers. Robo financial planner will help to mix-and-match best products based on inference of loan purpose and financial stability.

# %% [markdown]
# ![ML%20Capabilities%20and%20Applications.JPG](https://raw.githubusercontent.com/andrewwongls/dsc-4-final-project-online-ds-sp-000/master/ML%20Capabilities%20and%20Applications.JPG)

# %% [markdown]
# > **Agile Development**

# %% [markdown]
# In a typical agile development team, it comprises of 9-10 team members with the following roles:
# 1. Scrum Master - act like a servant leader to help team remove impediments.
# 2. Product Owner - act like a technical product manager, managing product backlog.
# 3. Development team - consist of developers and testers.
#
# In the world of Agile Product Data Science, I'd propose the following:
# 1. Scrum Master - act like a servant leader to help team remove impediments.
# 2. Product Owner - act like a technical product manager, managing product backlog, and a storyteller.
# 3. Data Modeler - the data specialist in the team to provide statistical and modeling service to the team.
# 4. Data Engineers - consist of developers and testers who can help to move data science algorithm (in Jupyter notebook form, or others) into production ready for MVP.

# %% [markdown]
# # CONCLUSIONS

# %% [markdown]
# This project has been rewarding experience in many fronts.
#
# First, I have started to form the view of Data Science from product development and management perspective. Through Design Sprint, I bring on-board the discipline of keep thinking about the problem and solution space in short cycle (5 days max!)
#
# Second, I have started to form the view of Data Science from agile development perspective. Through Agile Development, I bring on-board the discipline of build data science product through the lens of multi-disciplinary team based on the following guidelines:
# 1. Iterative modeling.
# 2. Deliver small, but consumable, increments in algorithms and prototypes.
# 3. Fast feedback cycles.
# 4. Predictive needs/requirements are evaluated continuous as a natural mechanism for responding to change quickly.
# 5. Continuous improving data and modeling
#
# Third, I have formed a good view about where I should invest more time as I go through the data science workflow (i.e. data scrubbing), and where the greatest values lies in the data science (i.e. building domain knowledge, feature engineering, and storytelling).
#
# Fourth, as I mentioned in the earlier point, I'd like to elaborate a bit more about data science storytelling. I believe it is getting more and more valuable for a data scientist to tell a good story. A good story means it is weavingly memorable - something that reader can connect the complexity of dataset, predictive algorithm and product design.
#
# I'd like to round up my learning from point #1 to #4 with a venn diagram (the original credit to Drew Conway) with introduction of Product Data Scientist.
#
#
# ![Product%20Data%20Scientist.JPG](https://raw.githubusercontent.com/andrewwongls/dsc-4-final-project-online-ds-sp-000/master/Product%20Data%20Scientist.JPG)
#
#
# Fifth, I would developing predictive modeling is the easier part of the data science workflow (surprisingly!). There are plenty of models library out there. The key success factors here are - having a sufficiently clean dataset, and appropriately feature engineered dataset.
#
# Lastly, this will be something that I will be experimenting in the next project - to move my local processing to the cloud!
#
# **Thank you for your time in reading this Jupyter Notebook.**
